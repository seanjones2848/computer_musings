# %%
from __future__ import print_function
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.layers import LSTM
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
import numpy as np
import random
import sys
# Out:
# Using TensorFlow backend.

# %%
target = open(str(raw_input("what file do you want to put it in?")), 'a+')
# Out:
# what file do you want to put it in?butts.txt

# %%
target
# Out:
# <open file 'butts.txt', mode 'a+' at 0x7f95c4671420>

# %%
path = get_file('ulthhg.txt', origin='http://138.68.236.150:42000/ulthhg.txt')

# %%
text = open(path).read().lower()

# %%
print('corpus length:', len(text))
# Out:
# corpus length: 1567706

# %%
chars = sorted(list(set(text)))

# %%
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))

# %%
maxlen = 40
step = 3
sentences = []
next_chars = []

# %%
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])

# %%
sentences
# Out:
# [' \n \ndouglas adams  \n \nthe ultimate \nhitc',
#  '\ndouglas adams  \n \nthe ultimate \nhitchhi',
#  'uglas adams  \n \nthe ultimate \nhitchhiker',
#  "as adams  \n \nthe ultimate \nhitchhiker's ",
#  "adams  \n \nthe ultimate \nhitchhiker's gui",
#  "ms  \n \nthe ultimate \nhitchhiker's guide ",
#  " \n \nthe ultimate \nhitchhiker's guide  \n ",
#  "\nthe ultimate \nhitchhiker's guide  \n \nco",
#  "e ultimate \nhitchhiker's guide  \n \ncompl",
#  "ltimate \nhitchhiker's guide  \n \ncomplete",
#  "mate \nhitchhiker's guide  \n \ncomplete & ",
#  "e \nhitchhiker's guide  \n \ncomplete & una",
#  "hitchhiker's guide  \n \ncomplete & unabri",
#  "chhiker's guide  \n \ncomplete & unabridge",
#  "iker's guide  \n \ncomplete & unabridged  ",
#  "r's guide  \n \ncomplete & unabridged  \n \n",
#  ' guide  \n \ncomplete & unabridged  \n \n \nc',
#  'ide  \n \ncomplete & unabridged  \n \n \ncont',
#  '  \n \ncomplete & unabridged  \n \n \ncontent',
#  ' \ncomplete & unabridged  \n \n \ncontents: ',
#  'omplete & unabridged  \n \n \ncontents:  \n ',
#  'lete & unabridged  \n \n \ncontents:  \n \n \n',
#  'e & unabridged  \n \n \ncontents:  \n \n \nint',
#  ' unabridged  \n \n \ncontents:  \n \n \nintrod',
#  'abridged  \n \n \ncontents:  \n \n \nintroduct',
#  'idged  \n \n \ncontents:  \n \n \nintroduction',
#  'ed  \n \n \ncontents:  \n \n \nintroduction: a',
#  ' \n \n \ncontents:  \n \n \nintroduction: a gu',
#  '\n \ncontents:  \n \n \nintroduction: a guide',
#  'contents:  \n \n \nintroduction: a guide to',
#  'tents:  \n \n \nintroduction: a guide to th',
#  'ts:  \n \n \nintroduction: a guide to the g',
#  '  \n \n \nintroduction: a guide to the guid',
#  ' \n \nintroduction: a guide to the guide  ',
#  '\nintroduction: a guide to the guide  \nth',
#  'troduction: a guide to the guide  \nthe h',
#  'duction: a guide to the guide  \nthe hitc',
#  'tion: a guide to the guide  \nthe hitchhi',
#  'n: a guide to the guide  \nthe hitchhiker',
#  "a guide to the guide  \nthe hitchhiker's ",
#  "uide to the guide  \nthe hitchhiker's gui",
#  "e to the guide  \nthe hitchhiker's guide ",
#  "o the guide  \nthe hitchhiker's guide to ",
#  "he guide  \nthe hitchhiker's guide to the",
#  "guide  \nthe hitchhiker's guide to the ga",
#  "de  \nthe hitchhiker's guide to the galax",
#  " \nthe hitchhiker's guide to the galaxy  ",
#  "he hitchhiker's guide to the galaxy  \nth",
#  "hitchhiker's guide to the galaxy  \nthe r",
#  "chhiker's guide to the galaxy  \nthe rest",
#  "iker's guide to the galaxy  \nthe restaur",
#  "r's guide to the galaxy  \nthe restaurant",
#  ' guide to the galaxy  \nthe restaurant at',
#  'ide to the galaxy  \nthe restaurant at th',
#  ' to the galaxy  \nthe restaurant at the e',
#  ' the galaxy  \nthe restaurant at the end ',
#  'e galaxy  \nthe restaurant at the end of ',
#  'alaxy  \nthe restaurant at the end of the',
#  'xy  \nthe restaurant at the end of the un',
#  ' \nthe restaurant at the end of the unive',
#  'he restaurant at the end of the universe',
#  'restaurant at the end of the universe  \n',
#  'taurant at the end of the universe  \nlif',
#  'rant at the end of the universe  \nlife, ',
#  't at the end of the universe  \nlife, the',
#  't the end of the universe  \nlife, the un',
#  'he end of the universe  \nlife, the unive',
#  'end of the universe  \nlife, the universe',
#  ' of the universe  \nlife, the universe an',
#  ' the universe  \nlife, the universe and e',
#  'e universe  \nlife, the universe and ever',
#  'niverse  \nlife, the universe and everyth',
#  'erse  \nlife, the universe and everything',
#  'e  \nlife, the universe and everything  \n',
#  '\nlife, the universe and everything  \nso ',
#  'fe, the universe and everything  \nso lon',
#  ' the universe and everything  \nso long, ',
#  'e universe and everything  \nso long, and',
#  'niverse and everything  \nso long, and th',
#  'erse and everything  \nso long, and thank',
#  'e and everything  \nso long, and thanks f',
#  'nd everything  \nso long, and thanks for ',
#  'everything  \nso long, and thanks for all',
#  'rything  \nso long, and thanks for all th',
#  'hing  \nso long, and thanks for all the f',
#  'g  \nso long, and thanks for all the fish',
#  '\nso long, and thanks for all the fish  \n',
#  ' long, and thanks for all the fish  \nyou',
#  'ng, and thanks for all the fish  \nyoung ',
#  ' and thanks for all the fish  \nyoung zap',
#  'd thanks for all the fish  \nyoung zaphod',
#  'hanks for all the fish  \nyoung zaphod pl',
#  'ks for all the fish  \nyoung zaphod plays',
#  'for all the fish  \nyoung zaphod plays it',
#  ' all the fish  \nyoung zaphod plays it sa',
#  'l the fish  \nyoung zaphod plays it safe ',
#  'he fish  \nyoung zaphod plays it safe  \nm',
#  'fish  \nyoung zaphod plays it safe  \nmost',
#  'h  \nyoung zaphod plays it safe  \nmostly ',
#  '\nyoung zaphod plays it safe  \nmostly har',
#  'ung zaphod plays it safe  \nmostly harmle',
#  ' zaphod plays it safe  \nmostly harmless ',
#  'phod plays it safe  \nmostly harmless  \nf',
#  'd plays it safe  \nmostly harmless  \nfoot',
#  'lays it safe  \nmostly harmless  \nfootnot',
#  's it safe  \nmostly harmless  \nfootnotes ',
#  't safe  \nmostly harmless  \nfootnotes  \n ',
#  'afe  \nmostly harmless  \nfootnotes  \n \n \n',
#  '  \nmostly harmless  \nfootnotes  \n \n \n in',
#  'mostly harmless  \nfootnotes  \n \n \n intro',
#  'tly harmless  \nfootnotes  \n \n \n introduc',
#  ' harmless  \nfootnotes  \n \n \n introductio',
#  'rmless  \nfootnotes  \n \n \n introduction: ',
#  'ess  \nfootnotes  \n \n \n introduction: a g',
#  '  \nfootnotes  \n \n \n introduction: a guid',
#  'footnotes  \n \n \n introduction: a guide t',
#  'tnotes  \n \n \n introduction: a guide to \n',
#  'tes  \n \n \n introduction: a guide to \nthe',
#  '  \n \n \n introduction: a guide to \nthe gu',
#  ' \n \n introduction: a guide to \nthe guide',
#  '\n introduction: a guide to \nthe guide \n ',
#  'ntroduction: a guide to \nthe guide \n \nso',
#  'oduction: a guide to \nthe guide \n \nsome ',
#  'ction: a guide to \nthe guide \n \nsome unh',
#  'on: a guide to \nthe guide \n \nsome unhelp',
#  ' a guide to \nthe guide \n \nsome unhelpful',
#  'guide to \nthe guide \n \nsome unhelpful re',
#  'de to \nthe guide \n \nsome unhelpful remar',
#  'to \nthe guide \n \nsome unhelpful remarks ',
#  '\nthe guide \n \nsome unhelpful remarks fro',
#  'e guide \n \nsome unhelpful remarks from t',
#  'uide \n \nsome unhelpful remarks from the ',
#  'e \n \nsome unhelpful remarks from the aut',
#  ' \nsome unhelpful remarks from the author',
#  'ome unhelpful remarks from the author  \n',
#  ' unhelpful remarks from the author  \n \nt',
#  'helpful remarks from the author  \n \nthe ',
#  'pful remarks from the author  \n \nthe his',
#  'l remarks from the author  \n \nthe histor',
#  'emarks from the author  \n \nthe history o',
#  'rks from the author  \n \nthe history of t',
#  ' from the author  \n \nthe history of the ',
#  'om the author  \n \nthe history of the hit',
#  'the author  \n \nthe history of the hitchh',
#  ' author  \n \nthe history of the hitchhike',
#  "thor  \n \nthe history of the hitchhiker's",
#  "r  \n \nthe history of the hitchhiker's gu",
#  "\n \nthe history of the hitchhiker's guide",
#  "the history of the hitchhiker's guide to",
#  " history of the hitchhiker's guide to th",
#  "story of the hitchhiker's guide to the g",
#  "ry of the hitchhiker's guide to the gala",
#  "of the hitchhiker's guide to the galaxy ",
#  "the hitchhiker's guide to the galaxy is ",
#  " hitchhiker's guide to the galaxy is now",
#  "tchhiker's guide to the galaxy is now so",
#  "hiker's guide to the galaxy is now so \nc",
#  "er's guide to the galaxy is now so \ncomp",
#  's guide to the galaxy is now so \ncomplic',
#  'uide to the galaxy is now so \ncomplicate',
#  'e to the galaxy is now so \ncomplicated t',
#  'o the galaxy is now so \ncomplicated that',
#  'he galaxy is now so \ncomplicated that ev',
#  'galaxy is now so \ncomplicated that every',
#  'axy is now so \ncomplicated that every ti',
#  ' is now so \ncomplicated that every time ',
#  ' now so \ncomplicated that every time i t',
#  'w so \ncomplicated that every time i tell',
#  'o \ncomplicated that every time i tell it',
#  'complicated that every time i tell it i ',
#  'plicated that every time i tell it i con',
#  'cated that every time i tell it i contra',
#  'ed that every time i tell it i contradic',
#  'that every time i tell it i contradict m',
#  't every time i tell it i contradict myse',
#  'very time i tell it i contradict myself,',
#  'y time i tell it i contradict myself, an',
#  'ime i tell it i contradict myself, and w',
#  ' i tell it i contradict myself, and when',
#  'tell it i contradict myself, and wheneve',
#  'l it i contradict myself, and whenever \n',
#  't i contradict myself, and whenever \ni d',
#  ' contradict myself, and whenever \ni do g',
#  'ntradict myself, and whenever \ni do get ',
#  'adict myself, and whenever \ni do get it ',
#  'ct myself, and whenever \ni do get it rig',
#  'myself, and whenever \ni do get it right ',
#  "elf, and whenever \ni do get it right i'm",
#  ", and whenever \ni do get it right i'm mi",
#  "nd whenever \ni do get it right i'm misqu",
#  "whenever \ni do get it right i'm misquote",
#  "never \ni do get it right i'm misquoted. ",
#  "er \ni do get it right i'm misquoted. so ",
#  "\ni do get it right i'm misquoted. so the",
#  "do get it right i'm misquoted. so the pu",
#  "get it right i'm misquoted. so the publi",
#  " it right i'm misquoted. so the publicat",
#  " right i'm misquoted. so the publication",
#  "ght i'm misquoted. so the publication of",
#  " i'm misquoted. so the publication of th",
#  'm misquoted. so the publication of this ',
#  'isquoted. so the publication of this omn',
#  'uoted. so the publication of this omnibu',
#  'ed. so the publication of this omnibus \n',
#  ' so the publication of this omnibus \nedi',
#  ' the publication of this omnibus \neditio',
#  'e publication of this omnibus \nedition s',
#  'ublication of this omnibus \nedition seem',
#  'ication of this omnibus \nedition seemed ',
#  'tion of this omnibus \nedition seemed lik',
#  'n of this omnibus \nedition seemed like a',
#  'f this omnibus \nedition seemed like a go',
#  'his omnibus \nedition seemed like a good ',
#  ' omnibus \nedition seemed like a good opp',
#  'nibus \nedition seemed like a good opport',
#  'us \nedition seemed like a good opportuni',
#  '\nedition seemed like a good opportunity ',
#  'ition seemed like a good opportunity to ',
#  'on seemed like a good opportunity to set',
#  'seemed like a good opportunity to set th',
#  'med like a good opportunity to set the r',
#  ' like a good opportunity to set the reco',
#  'ke a good opportunity to set the record ',
#  'a good opportunity to set the record str',
#  'ood opportunity to set the record straig',
#  ' opportunity to set the record straight ',
#  'portunity to set the record straight \xca\xb9 ',
#  'tunity to set the record straight \xca\xb9 or ',
#  'ity to set the record straight \xca\xb9 or \nat',
#  ' to set the record straight \xca\xb9 or \nat le',
#  ' set the record straight \xca\xb9 or \nat least',
#  't the record straight \xca\xb9 or \nat least fi',
#  'he record straight \xca\xb9 or \nat least firml',
#  'record straight \xca\xb9 or \nat least firmly c',
#  'ord straight \xca\xb9 or \nat least firmly croo',
#  ' straight \xca\xb9 or \nat least firmly crooked',
#  'raight \xca\xb9 or \nat least firmly crooked. a',
#  'ght \xca\xb9 or \nat least firmly crooked. anyt',
#  ' \xca\xb9 or \nat least firmly crooked. anythin',
#  ' or \nat least firmly crooked. anything t',
#  ' \nat least firmly crooked. anything that',
#  't least firmly crooked. anything that is',
#  'east firmly crooked. anything that is pu',
#  't firmly crooked. anything that is put d',
#  'irmly crooked. anything that is put down',
#  'ly crooked. anything that is put down wr',
#  'crooked. anything that is put down wrong',
#  'oked. anything that is put down wrong he',
#  'd. anything that is put down wrong here ',
#  'anything that is put down wrong here is,',
#  'thing that is put down wrong here is, as',
#  'ng that is put down wrong here is, as fa',
#  'that is put down wrong here is, as far \n',
#  't is put down wrong here is, as far \nas ',
#  "s put down wrong here is, as far \nas i'm",
#  "ut down wrong here is, as far \nas i'm co",
#  "down wrong here is, as far \nas i'm conce",
#  "n wrong here is, as far \nas i'm concerne",
#  "rong here is, as far \nas i'm concerned, ",
#  "g here is, as far \nas i'm concerned, wro",
#  "ere is, as far \nas i'm concerned, wrong ",
#  " is, as far \nas i'm concerned, wrong for",
#  ", as far \nas i'm concerned, wrong for go",
#  "s far \nas i'm concerned, wrong for good.",
#  "ar \nas i'm concerned, wrong for good.  \n",
#  "\nas i'm concerned, wrong for good.  \nthe",
#  " i'm concerned, wrong for good.  \nthe id",
#  'm concerned, wrong for good.  \nthe idea ',
#  'oncerned, wrong for good.  \nthe idea for',
#  'erned, wrong for good.  \nthe idea for th',
#  'ed, wrong for good.  \nthe idea for the t',
#  ' wrong for good.  \nthe idea for the titl',
#  'ong for good.  \nthe idea for the title f',
#  ' for good.  \nthe idea for the title firs',
#  'r good.  \nthe idea for the title first c',
#  'ood.  \nthe idea for the title first crop',
#  '.  \nthe idea for the title first cropped',
#  '\nthe idea for the title first cropped up',
#  'e idea for the title first cropped up wh',
#  'dea for the title first cropped up while',
#  ' for the title first cropped up while i ',
#  'r the title first cropped up while i was',
#  'he title first cropped up while i was ly',
#  'title first cropped up while i was lying',
#  'le first cropped up while i was lying dr',
#  'first cropped up while i was lying drunk',
#  'st cropped up while i was lying drunk in',
#  'cropped up while i was lying drunk in a ',
#  'pped up while i was lying drunk in a \nfi',
#  'd up while i was lying drunk in a \nfield',
#  'p while i was lying drunk in a \nfield in',
#  'hile i was lying drunk in a \nfield in in',
#  'e i was lying drunk in a \nfield in innsb',
#  ' was lying drunk in a \nfield in innsbruc',
#  's lying drunk in a \nfield in innsbruck, ',
#  'ying drunk in a \nfield in innsbruck, aus',
#  'g drunk in a \nfield in innsbruck, austri',
#  'runk in a \nfield in innsbruck, austria, ',
#  'k in a \nfield in innsbruck, austria, in ',
#  'n a \nfield in innsbruck, austria, in 197',
#  ' \nfield in innsbruck, austria, in 1971. ',
#  'ield in innsbruck, austria, in 1971. not',
#  'd in innsbruck, austria, in 1971. not pa',
#  'n innsbruck, austria, in 1971. not parti',
#  'nnsbruck, austria, in 1971. not particul',
#  'bruck, austria, in 1971. not particularl',
#  'ck, austria, in 1971. not particularly d',
#  ' austria, in 1971. not particularly drun',
#  'stria, in 1971. not particularly drunk, ',
#  'ia, in 1971. not particularly drunk, jus',
#  ' in 1971. not particularly drunk, just t',
#  ' 1971. not particularly drunk, just the ',
#  '71. not particularly drunk, just the \nso',
#  ' not particularly drunk, just the \nsort ',
#  't particularly drunk, just the \nsort of ',
#  'articularly drunk, just the \nsort of dru',
#  'icularly drunk, just the \nsort of drunk ',
#  'larly drunk, just the \nsort of drunk you',
#  'ly drunk, just the \nsort of drunk you ge',
#  'drunk, just the \nsort of drunk you get w',
#  'nk, just the \nsort of drunk you get when',
#  ' just the \nsort of drunk you get when yo',
#  'st the \nsort of drunk you get when you h',
#  'the \nsort of drunk you get when you have',
#  ' \nsort of drunk you get when you have a ',
#  'ort of drunk you get when you have a cou',
#  ' of drunk you get when you have a couple',
#  ' drunk you get when you have a couple of',
#  'unk you get when you have a couple of st',
#  ' you get when you have a couple of stiff',
#  'u get when you have a couple of stiff g\xc3',
#  'et when you have a couple of stiff g\xc3\xb6ss',
#  'when you have a couple of stiff g\xc3\xb6ssers',
#  'n you have a couple of stiff g\xc3\xb6ssers af',
#  'ou have a couple of stiff g\xc3\xb6ssers after',
#  'have a couple of stiff g\xc3\xb6ssers after \nn',
#  'e a couple of stiff g\xc3\xb6ssers after \nnot ',
#  ' couple of stiff g\xc3\xb6ssers after \nnot hav',
#  'uple of stiff g\xc3\xb6ssers after \nnot having',
#  'e of stiff g\xc3\xb6ssers after \nnot having ea',
#  'f stiff g\xc3\xb6ssers after \nnot having eaten',
#  'tiff g\xc3\xb6ssers after \nnot having eaten fo',
#  'f g\xc3\xb6ssers after \nnot having eaten for t',
#  '\xc3\xb6ssers after \nnot having eaten for two ',
#  'sers after \nnot having eaten for two day',
#  's after \nnot having eaten for two days s',
#  'fter \nnot having eaten for two days stra',
#  'r \nnot having eaten for two days straigh',
#  'not having eaten for two days straight, ',
#  ' having eaten for two days straight, on ',
#  'ving eaten for two days straight, on acc',
#  'g eaten for two days straight, on accoun',
#  'aten for two days straight, on account o',
#  'n for two days straight, on account of b',
#  'or two days straight, on account of bein',
#  'two days straight, on account of being a',
#  ' days straight, on account of being a \np',
#  'ys straight, on account of being a \npenn',
#  'straight, on account of being a \npennile',
#  'aight, on account of being a \npenniless ',
#  'ht, on account of being a \npenniless hit',
#  ' on account of being a \npenniless hitchh',
#  ' account of being a \npenniless hitchhike',
#  'count of being a \npenniless hitchhiker. ',
#  'nt of being a \npenniless hitchhiker. we ',
#  'of being a \npenniless hitchhiker. we are',
#  'being a \npenniless hitchhiker. we are ta',
#  'ng a \npenniless hitchhiker. we are talki',
#  'a \npenniless hitchhiker. we are talking ',
#  'penniless hitchhiker. we are talking of ',
#  'niless hitchhiker. we are talking of a m',
#  'ess hitchhiker. we are talking of a mild',
#  ' hitchhiker. we are talking of a mild in',
#  'tchhiker. we are talking of a mild inabi',
#  'hiker. we are talking of a mild inabilit',
#  'er. we are talking of a mild inability t',
#  ' we are talking of a mild inability to s',
#  ' are talking of a mild inability to stan',
#  'e talking of a mild inability to stand u',
#  'alking of a mild inability to stand up. ',
#  'ing of a mild inability to stand up.  \ni',
#  ' of a mild inability to stand up.  \ni wa',
#  ' a mild inability to stand up.  \ni was t',
#  'mild inability to stand up.  \ni was trav',
#  'd inability to stand up.  \ni was traveli',
#  'nability to stand up.  \ni was traveling ',
#  'ility to stand up.  \ni was traveling wit',
#  'ty to stand up.  \ni was traveling with a',
#  'to stand up.  \ni was traveling with a co',
#  'stand up.  \ni was traveling with a copy ',
#  'nd up.  \ni was traveling with a copy of ',
#  'up.  \ni was traveling with a copy of the',
#  '  \ni was traveling with a copy of the hi',
#  'i was traveling with a copy of the hitch',
#  'as traveling with a copy of the hitch hi',
#  'traveling with a copy of the hitch hiker',
#  'veling with a copy of the hitch hiker s ',
#  'ing with a copy of the hitch hiker s gui',
#  ' with a copy of the hitch hiker s guide ',
#  'th a copy of the hitch hiker s guide to ',
#  'a copy of the hitch hiker s guide to eur',
#  'opy of the hitch hiker s guide to europe',
#  ' of the hitch hiker s guide to europe by',
#  ' the hitch hiker s guide to europe by \nk',
#  'e hitch hiker s guide to europe by \nken ',
#  'itch hiker s guide to europe by \nken wal',
#  'h hiker s guide to europe by \nken walsh,',
#  'iker s guide to europe by \nken walsh, a ',
#  'r s guide to europe by \nken walsh, a ver',
#  ' guide to europe by \nken walsh, a very b',
#  'ide to europe by \nken walsh, a very batt',
#  ' to europe by \nken walsh, a very battere',
#  ' europe by \nken walsh, a very battered c',
#  'rope by \nken walsh, a very battered copy',
#  'e by \nken walsh, a very battered copy th',
#  'y \nken walsh, a very battered copy that ',
#  'ken walsh, a very battered copy that i h',
#  ' walsh, a very battered copy that i had ',
#  'lsh, a very battered copy that i had bor',
#  ', a very battered copy that i had borrow',
#  ' very battered copy that i had borrowed ',
#  'ry battered copy that i had borrowed fro',
#  'battered copy that i had borrowed from s',
#  'tered copy that i had borrowed from some',
#  'ed copy that i had borrowed from someone',
#  'copy that i had borrowed from someone. \n',
#  'y that i had borrowed from someone. \nin ',
#  'hat i had borrowed from someone. \nin fac',
#  ' i had borrowed from someone. \nin fact, ',
#  'had borrowed from someone. \nin fact, sin',
#  ' borrowed from someone. \nin fact, since ',
#  'rrowed from someone. \nin fact, since thi',
#  'wed from someone. \nin fact, since this w',
#  ' from someone. \nin fact, since this was ',
#  'om someone. \nin fact, since this was 197',
#  'someone. \nin fact, since this was 1971 a',
#  'eone. \nin fact, since this was 1971 and ',
#  'e. \nin fact, since this was 1971 and i s',
#  '\nin fact, since this was 1971 and i stil',
#  ' fact, since this was 1971 and i still h',
#  'ct, since this was 1971 and i still have',
#  ' since this was 1971 and i still have th',
#  'nce this was 1971 and i still have the b',
#  ' this was 1971 and i still have the book',
#  'is was 1971 and i still have the book, i',
#  'was 1971 and i still have the book, it m',
#  ' 1971 and i still have the book, it must',
#  '71 and i still have the book, it must co',
#  'and i still have the book, it must count',
#  ' i still have the book, it must count as',
#  'still have the book, it must count as \ns',
#  'll have the book, it must count as \nstol',
#  'have the book, it must count as \nstolen ',
#  'e the book, it must count as \nstolen by ',
#  'he book, it must count as \nstolen by now',
#  'book, it must count as \nstolen by now. i',
#  'k, it must count as \nstolen by now. i di',
#  "it must count as \nstolen by now. i didn'",
#  "must count as \nstolen by now. i didn't h",
#  "t count as \nstolen by now. i didn't have",
#  "ount as \nstolen by now. i didn't have a ",
#  "t as \nstolen by now. i didn't have a cop",
#  "s \nstolen by now. i didn't have a copy o",
#  "stolen by now. i didn't have a copy of e",
#  "len by now. i didn't have a copy of euro",
#  " by now. i didn't have a copy of europe ",
#  " now. i didn't have a copy of europe on ",
#  "w. i didn't have a copy of europe on fiv",
#  "i didn't have a copy of europe on five d",
#  "idn't have a copy of europe on five doll",
#  "'t have a copy of europe on five dollars",
#  'have a copy of europe on five dollars a ',
#  'e a copy of europe on five dollars a day',
#  ' copy of europe on five dollars a day (a',
#  'py of europe on five dollars a day (as \n',
#  'of europe on five dollars a day (as \nit ',
#  'europe on five dollars a day (as \nit the',
#  'ope on five dollars a day (as \nit then w',
#  ' on five dollars a day (as \nit then was)',
#  ' five dollars a day (as \nit then was) be',
#  've dollars a day (as \nit then was) becau',
#  'dollars a day (as \nit then was) because ',
#  'lars a day (as \nit then was) because i w',
#  's a day (as \nit then was) because i wasn',
#  " day (as \nit then was) because i wasn't ",
#  "y (as \nit then was) because i wasn't in ",
#  "as \nit then was) because i wasn't in tha",
#  "\nit then was) because i wasn't in that f",
#  " then was) because i wasn't in that fina",
#  "en was) because i wasn't in that financi",
#  "was) because i wasn't in that financial ",
#  ") because i wasn't in that financial lea",
#  "ecause i wasn't in that financial league",
#  "use i wasn't in that financial league.  ",
#  " i wasn't in that financial league.  \nni",
#  "wasn't in that financial league.  \nnight",
#  "n't in that financial league.  \nnight wa",
#  ' in that financial league.  \nnight was b',
#  ' that financial league.  \nnight was begi',
#  'at financial league.  \nnight was beginni',
#  'financial league.  \nnight was beginning ',
#  'ancial league.  \nnight was beginning to ',
#  'ial league.  \nnight was beginning to fal',
#  ' league.  \nnight was beginning to fall o',
#  'ague.  \nnight was beginning to fall on m',
#  'e.  \nnight was beginning to fall on my f',
#  ' \nnight was beginning to fall on my fiel',
#  'ight was beginning to fall on my field a',
#  't was beginning to fall on my field as i',
#  'as beginning to fall on my field as it s',
#  'beginning to fall on my field as it spun',
#  'inning to fall on my field as it spun la',
#  'ing to fall on my field as it spun lazil',
#  ' to fall on my field as it spun lazily u',
#  ' fall on my field as it spun lazily unde',
#  'll on my field as it spun lazily underne',
#  'on my field as it spun lazily underneath',
#  'my field as it spun lazily underneath \nm',
#  'field as it spun lazily underneath \nme. ',
#  'ld as it spun lazily underneath \nme. i w',
#  'as it spun lazily underneath \nme. i was ',
#  'it spun lazily underneath \nme. i was won',
#  'spun lazily underneath \nme. i was wonder',
#  'n lazily underneath \nme. i was wondering',
#  'azily underneath \nme. i was wondering wh',
#  'ly underneath \nme. i was wondering where',
#  'underneath \nme. i was wondering where i ',
#  'erneath \nme. i was wondering where i cou',
#  'eath \nme. i was wondering where i could ',
#  'h \nme. i was wondering where i could go ',
#  'me. i was wondering where i could go tha',
#  ' i was wondering where i could go that w',
#  'was wondering where i could go that was ',
#  ' wondering where i could go that was che',
#  'ndering where i could go that was cheape',
#  'ring where i could go that was cheaper t',
#  'g where i could go that was cheaper than',
#  'here i could go that was cheaper than \ni',
#  'e i could go that was cheaper than \ninns',
#  ' could go that was cheaper than \ninnsbru',
#  'uld go that was cheaper than \ninnsbruck,',
#  ' go that was cheaper than \ninnsbruck, re',
#  ' that was cheaper than \ninnsbruck, revol',
#  'at was cheaper than \ninnsbruck, revolved',
#  'was cheaper than \ninnsbruck, revolved le',
#  ' cheaper than \ninnsbruck, revolved less ',
#  'eaper than \ninnsbruck, revolved less and',
#  'er than \ninnsbruck, revolved less and di',
#  "than \ninnsbruck, revolved less and didn'",
#  "n \ninnsbruck, revolved less and didn't d",
#  "innsbruck, revolved less and didn't do t",
#  "sbruck, revolved less and didn't do the ",
#  "uck, revolved less and didn't do the sor",
#  ", revolved less and didn't do the sort o",
#  "evolved less and didn't do the sort of t",
#  "lved less and didn't do the sort of thin",
#  "d less and didn't do the sort of things ",
#  "ess and didn't do the sort of things to ",
#  " and didn't do the sort of things to me ",
#  "d didn't do the sort of things to me tha",
#  "idn't do the sort of things to me that \n",
#  "'t do the sort of things to me that \ninn",
#  'do the sort of things to me that \ninnsbr',
#  'the sort of things to me that \ninnsbruck',
#  ' sort of things to me that \ninnsbruck ha',
#  'rt of things to me that \ninnsbruck had d',
#  'of things to me that \ninnsbruck had done',
#  'things to me that \ninnsbruck had done to',
#  'ngs to me that \ninnsbruck had done to me',
#  ' to me that \ninnsbruck had done to me th',
#  ' me that \ninnsbruck had done to me that ',
#  ' that \ninnsbruck had done to me that aft',
#  'at \ninnsbruck had done to me that aftern',
#  '\ninnsbruck had done to me that afternoon',
#  'nsbruck had done to me that afternoon. w',
#  'ruck had done to me that afternoon. what',
#  'k had done to me that afternoon. what ha',
#  'ad done to me that afternoon. what had h',
#  'done to me that afternoon. what had happ',
#  'e to me that afternoon. what had happene',
#  'o me that afternoon. what had happened w',
#  'e that afternoon. what had happened was ',
#  'hat afternoon. what had happened was \nth',
#  ' afternoon. what had happened was \nthis.',
#  'ternoon. what had happened was \nthis. i ',
#  'noon. what had happened was \nthis. i had',
#  'n. what had happened was \nthis. i had be',
#  'what had happened was \nthis. i had been ',
#  't had happened was \nthis. i had been wal',
#  'ad happened was \nthis. i had been walkin',
#  'happened was \nthis. i had been walking t',
#  'pened was \nthis. i had been walking thro',
#  'ed was \nthis. i had been walking through',
#  'was \nthis. i had been walking through th',
#  ' \nthis. i had been walking through the t',
#  'his. i had been walking through the town',
#  '. i had been walking through the town tr',
#  ' had been walking through the town tryin',
#  'd been walking through the town trying t',
#  'een walking through the town trying to f',
#  ' walking through the town trying to find',
#  'lking through the town trying to find a ',
#  'ng through the town trying to find a par',
#  'through the town trying to find a partic',
#  'ough the town trying to find a particula',
#  'h the town trying to find a particular \n',
#  'he town trying to find a particular \nadd',
#  'town trying to find a particular \naddres',
#  'n trying to find a particular \naddress, ',
#  'rying to find a particular \naddress, and',
#  'ng to find a particular \naddress, and be',
#  'to find a particular \naddress, and being',
#  'find a particular \naddress, and being th',
#  'd a particular \naddress, and being thoro',
#  ' particular \naddress, and being thorough',
#  'rticular \naddress, and being thoroughly ',
#  'cular \naddress, and being thoroughly los',
#  'ar \naddress, and being thoroughly lost i',
#  '\naddress, and being thoroughly lost i st',
#  'dress, and being thoroughly lost i stopp',
#  'ss, and being thoroughly lost i stopped ',
#  ' and being thoroughly lost i stopped to ',
#  'd being thoroughly lost i stopped to ask',
#  'eing thoroughly lost i stopped to ask fo',
#  'g thoroughly lost i stopped to ask for d',
#  'horoughly lost i stopped to ask for dire',
#  'oughly lost i stopped to ask for directi',
#  'hly lost i stopped to ask for directions',
#  ' lost i stopped to ask for directions \nf',
#  'st i stopped to ask for directions \nfrom',
#  'i stopped to ask for directions \nfrom a ',
#  'topped to ask for directions \nfrom a man',
#  'ped to ask for directions \nfrom a man in',
#  ' to ask for directions \nfrom a man in th',
#  ' ask for directions \nfrom a man in the s',
#  'k for directions \nfrom a man in the stre',
#  'or directions \nfrom a man in the street.',
#  'directions \nfrom a man in the street. i ',
#  'ections \nfrom a man in the street. i kne',
#  'ions \nfrom a man in the street. i knew t',
#  's \nfrom a man in the street. i knew this',
#  'from a man in the street. i knew this mi',
#  'm a man in the street. i knew this might',
#  " man in the street. i knew this mightn't",
#  "n in the street. i knew this mightn't be",
#  "n the street. i knew this mightn't be ea",
#  "he street. i knew this mightn't be easy ",
#  "street. i knew this mightn't be easy bec",
#  "eet. i knew this mightn't be easy becaus",
#  ". i knew this mightn't be easy because i",
#  " knew this mightn't be easy because i do",
#  "ew this mightn't be easy because i don't",
#  "this mightn't be easy because i don't \ns",
#  "s mightn't be easy because i don't \nspea",
#  "ightn't be easy because i don't \nspeak g",
#  "tn't be easy because i don't \nspeak germ",
#  "t be easy because i don't \nspeak german,",
#  "e easy because i don't \nspeak german, bu",
#  "asy because i don't \nspeak german, but i",
#  " because i don't \nspeak german, but i wa",
#  "cause i don't \nspeak german, but i was s",
#  "se i don't \nspeak german, but i was stil",
#  "i don't \nspeak german, but i was still s",
#  "on't \nspeak german, but i was still surp",
#  't \nspeak german, but i was still surpris',
#  'speak german, but i was still surprised ',
#  'ak german, but i was still surprised to ',
#  'german, but i was still surprised to dis',
#  'man, but i was still surprised to discov',
#  ', but i was still surprised to discover ',
#  'ut i was still surprised to discover jus',
#  'i was still surprised to discover just h',
#  'as still surprised to discover just how ',
#  'still surprised to discover just how muc',
#  'll surprised to discover just how much \n',
#  'surprised to discover just how much \ndif',
#  'prised to discover just how much \ndiffic',
#  'sed to discover just how much \ndifficult',
#  ' to discover just how much \ndifficulty i',
#  ' discover just how much \ndifficulty i wa',
#  'scover just how much \ndifficulty i was h',
#  'ver just how much \ndifficulty i was havi',
#  ' just how much \ndifficulty i was having ',
#  'st how much \ndifficulty i was having com',
#  'how much \ndifficulty i was having commun',
#  ' much \ndifficulty i was having communica',
#  'ch \ndifficulty i was having communicatin',
#  '\ndifficulty i was having communicating w',
#  'fficulty i was having communicating with',
#  'culty i was having communicating with th',
#  'ty i was having communicating with this ',
#  'i was having communicating with this par',
#  'as having communicating with this partic',
#  'having communicating with this particula',
#  'ing communicating with this particular m',
#  ' communicating with this particular man.',
#  'mmunicating with this particular man. \ng',
#  'nicating with this particular man. \ngrad',
#  'ating with this particular man. \ngradual',
#  'ng with this particular man. \ngradually ',
#  'with this particular man. \ngradually the',
#  'h this particular man. \ngradually the tr',
#  'his particular man. \ngradually the truth',
#  ' particular man. \ngradually the truth da',
#  'rticular man. \ngradually the truth dawne',
#  'cular man. \ngradually the truth dawned o',
#  'ar man. \ngradually the truth dawned on m',
#  'man. \ngradually the truth dawned on me a',
#  '. \ngradually the truth dawned on me as w',
#  'gradually the truth dawned on me as we s',
#  'dually the truth dawned on me as we stru',
#  'lly the truth dawned on me as we struggl',
#  ' the truth dawned on me as we struggled ',
#  'e truth dawned on me as we struggled in ',
#  'ruth dawned on me as we struggled in vai',
#  'h dawned on me as we struggled in vain t',
#  'awned on me as we struggled in vain to \n',
#  'ed on me as we struggled in vain to \nund',
#  'on me as we struggled in vain to \nunders',
#  'me as we struggled in vain to \nunderstan',
#  'as we struggled in vain to \nunderstand e',
#  'we struggled in vain to \nunderstand each',
#  'struggled in vain to \nunderstand each ot',
#  'uggled in vain to \nunderstand each other',
#  'led in vain to \nunderstand each other th',
#  ' in vain to \nunderstand each other that ',
#  ' vain to \nunderstand each other that of ',
#  'in to \nunderstand each other that of all',
#  'to \nunderstand each other that of all th',
#  '\nunderstand each other that of all the p',
#  'derstand each other that of all the peop',
#  'stand each other that of all the people ',
#  'nd each other that of all the people in ',
#  'each other that of all the people in inn',
#  'h other that of all the people in innsbr',
#  'ther that of all the people in innsbruck',
#  'r that of all the people in innsbruck i ',
#  'hat of all the people in innsbruck i cou',
#  ' of all the people in innsbruck i could ',
#  ' all the people in innsbruck i could hav',
#  'l the people in innsbruck i could have \n',
#  'he people in innsbruck i could have \nsto',
#  'people in innsbruck i could have \nstoppe',
#  'ple in innsbruck i could have \nstopped t',
#  ' in innsbruck i could have \nstopped to a',
#  ' innsbruck i could have \nstopped to ask,',
#  'nsbruck i could have \nstopped to ask, th',
#  'ruck i could have \nstopped to ask, the o',
#  'k i could have \nstopped to ask, the one ',
#  ' could have \nstopped to ask, the one i h',
#  'uld have \nstopped to ask, the one i had ',
#  ' have \nstopped to ask, the one i had pic',
#  've \nstopped to ask, the one i had picked',
#  '\nstopped to ask, the one i had picked di',
#  'opped to ask, the one i had picked did n',
#  'ed to ask, the one i had picked did not ',
#  'to ask, the one i had picked did not spe',
#  'ask, the one i had picked did not speak ',
#  ', the one i had picked did not speak eng',
#  'he one i had picked did not speak englis',
#  'one i had picked did not speak english, ',
#  ' i had picked did not speak english, did',
#  'had picked did not speak english, did no',
#  ' picked did not speak english, did not \n',
#  'cked did not speak english, did not \nspe',
#  'd did not speak english, did not \nspeak ',
#  'id not speak english, did not \nspeak fre',
#  'not speak english, did not \nspeak french',
#  ' speak english, did not \nspeak french an',
#  'eak english, did not \nspeak french and w',
#  ' english, did not \nspeak french and was ',
#  'glish, did not \nspeak french and was als',
#  'sh, did not \nspeak french and was also d',
#  ' did not \nspeak french and was also deaf',
#  'd not \nspeak french and was also deaf an',
#  'ot \nspeak french and was also deaf and d',
#  '\nspeak french and was also deaf and dumb',
#  'eak french and was also deaf and dumb. w',
#  ' french and was also deaf and dumb. with',
#  'ench and was also deaf and dumb. with a ',
#  'h and was also deaf and dumb. with a ser',
#  'nd was also deaf and dumb. with a series',
#  'was also deaf and dumb. with a series of',
#  ' also deaf and dumb. with a series of si',
#  'so deaf and dumb. with a series of since',
#  'deaf and dumb. with a series of sincerel',
#  'f and dumb. with a series of sincerely \n',
#  'nd dumb. with a series of sincerely \napo',
#  'dumb. with a series of sincerely \napolog',
#  'b. with a series of sincerely \napologeti',
#  'with a series of sincerely \napologetic h',
#  'h a series of sincerely \napologetic hand',
#  ' series of sincerely \napologetic hand mo',
#  'ries of sincerely \napologetic hand movem',
#  's of sincerely \napologetic hand movement',
#  'f sincerely \napologetic hand movements, ',
#  'incerely \napologetic hand movements, i d',
#  'erely \napologetic hand movements, i dise',
#  'ly \napologetic hand movements, i disenta',
#  '\napologetic hand movements, i disentangl',
#  'ologetic hand movements, i disentangled ',
#  'getic hand movements, i disentangled mys',
#  'ic hand movements, i disentangled myself',
#  'hand movements, i disentangled myself, a',
#  'd movements, i disentangled myself, and ',
#  'ovements, i disentangled myself, and a f',
#  'ments, i disentangled myself, and a few ',
#  'ts, i disentangled myself, and a few min',
#  ' i disentangled myself, and a few minute',
#  'disentangled myself, and a few minutes l',
#  'entangled myself, and a few minutes late',
#  'angled myself, and a few minutes later, ',
#  'led myself, and a few minutes later, on ',
#  ' myself, and a few minutes later, on ano',
#  'self, and a few minutes later, on anothe',
#  'f, and a few minutes later, on another s',
#  'and a few minutes later, on another stre',
#  ' a few minutes later, on another street,',
#  'few minutes later, on another street, i ',
#  ' minutes later, on another street, i sto',
#  'nutes later, on another street, i stoppe',
#  'es later, on another street, i stopped a',
#  'later, on another street, i stopped and ',
#  'er, on another street, i stopped and ask',
#  ' on another street, i stopped and asked ',
#  ' another street, i stopped and asked ano',
#  'other street, i stopped and asked anothe',
#  'er street, i stopped and asked another m',
#  'street, i stopped and asked another man ',
#  'eet, i stopped and asked another man \nwh',
#  ', i stopped and asked another man \nwho a',
#  ' stopped and asked another man \nwho also',
#  'opped and asked another man \nwho also tu',
#  'ed and asked another man \nwho also turne',
#  'and asked another man \nwho also turned o',
#  ' asked another man \nwho also turned out ',
#  'ked another man \nwho also turned out to ',
#  ' another man \nwho also turned out to be ',
#  'other man \nwho also turned out to be dea',
#  'er man \nwho also turned out to be deaf a',
#  'man \nwho also turned out to be deaf and ',
#  ' \nwho also turned out to be deaf and dum',
#  'ho also turned out to be deaf and dumb, ',
#  'also turned out to be deaf and dumb, whi',
#  'o turned out to be deaf and dumb, which ',
#  'urned out to be deaf and dumb, which was',
#  'ed out to be deaf and dumb, which was wh',
#  'out to be deaf and dumb, which was when ',
#  ' to be deaf and dumb, which was when i b',
#  ' be deaf and dumb, which was when i boug',
#  ' deaf and dumb, which was when i bought ',
#  'af and dumb, which was when i bought \nth',
#  'and dumb, which was when i bought \nthe b',
#  ' dumb, which was when i bought \nthe beer',
#  'mb, which was when i bought \nthe beers. ',
#  ' which was when i bought \nthe beers.  \ni',
#  'ich was when i bought \nthe beers.  \ni ve',
#  ' was when i bought \nthe beers.  \ni ventu',
#  's when i bought \nthe beers.  \ni ventured',
#  'hen i bought \nthe beers.  \ni ventured ba',
#  ' i bought \nthe beers.  \ni ventured back ',
#  'bought \nthe beers.  \ni ventured back ont',
#  'ght \nthe beers.  \ni ventured back onto t',
#  ' \nthe beers.  \ni ventured back onto the ',
#  'he beers.  \ni ventured back onto the str',
#  'beers.  \ni ventured back onto the street',
#  'rs.  \ni ventured back onto the street. i',
#  '  \ni ventured back onto the street. i tr',
#  'i ventured back onto the street. i tried',
#  'entured back onto the street. i tried ag',
#  'ured back onto the street. i tried again',
#  'd back onto the street. i tried again.  ',
#  'ack onto the street. i tried again.  \nwh',
#  ' onto the street. i tried again.  \nwhen ',
#  'to the street. i tried again.  \nwhen the',
#  'the street. i tried again.  \nwhen the th',
#  ' street. i tried again.  \nwhen the third',
#  'reet. i tried again.  \nwhen the third ma',
#  't. i tried again.  \nwhen the third man i',
#  'i tried again.  \nwhen the third man i sp',
#  'ried again.  \nwhen the third man i spoke',
#  'd again.  \nwhen the third man i spoke to',
#  'gain.  \nwhen the third man i spoke to tu',
#  'n.  \nwhen the third man i spoke to turne',
#  ' \nwhen the third man i spoke to turned o',
#  'hen the third man i spoke to turned out ',
#  ' the third man i spoke to turned out to ',
#  'e third man i spoke to turned out to be ',
#  'hird man i spoke to turned out to be dea',
#  'd man i spoke to turned out to be deaf a',
#  'an i spoke to turned out to be deaf and ',
#  'i spoke to turned out to be deaf and dum',
#  'poke to turned out to be deaf and dumb \n',
#  'e to turned out to be deaf and dumb \nand',
#  'o turned out to be deaf and dumb \nand al',
#  'urned out to be deaf and dumb \nand also ',
#  'ed out to be deaf and dumb \nand also bli',
#  'out to be deaf and dumb \nand also blind ',
#  ' to be deaf and dumb \nand also blind i b',
#  ' be deaf and dumb \nand also blind i bega',
#  ' deaf and dumb \nand also blind i began t',
#  'af and dumb \nand also blind i began to f',
#  'and dumb \nand also blind i began to feel',
#  ' dumb \nand also blind i began to feel a ',
#  'mb \nand also blind i began to feel a ter',
#  '\nand also blind i began to feel a terrib',
#  'd also blind i began to feel a terrible ',
#  'lso blind i began to feel a terrible wei',
#  ' blind i began to feel a terrible weight',
#  'ind i began to feel a terrible weight se',
#  ' i began to feel a terrible weight settl',
#  'began to feel a terrible weight settling',
#  'an to feel a terrible weight settling on',
#  'to feel a terrible weight settling on my',
#  'feel a terrible weight settling on my \ns',
#  'l a terrible weight settling on my \nshou',
#  ' terrible weight settling on my \nshoulde',
#  'rrible weight settling on my \nshoulders;',
#  'ble weight settling on my \nshoulders; wh',
#  ' weight settling on my \nshoulders; where',
#  'ight settling on my \nshoulders; wherever',
#  't settling on my \nshoulders; wherever i ',
#  'ettling on my \nshoulders; wherever i loo',
#  'ling on my \nshoulders; wherever i looked',
#  'g on my \nshoulders; wherever i looked th',
#  'n my \nshoulders; wherever i looked the t',
#  'y \nshoulders; wherever i looked the tree',
#  'shoulders; wherever i looked the trees a',
#  'ulders; wherever i looked the trees and ',
#  'ers; wherever i looked the trees and bui',
#  '; wherever i looked the trees and buildi',
#  'herever i looked the trees and buildings',
#  'ever i looked the trees and buildings to',
#  'r i looked the trees and buildings took ',
#  ' looked the trees and buildings took on ',
#  'oked the trees and buildings took on dar',
#  'd the trees and buildings took on dark a',
#  'he trees and buildings took on dark and ',
#  'trees and buildings took on dark and \nme',
#  'es and buildings took on dark and \nmenac',
#  'and buildings took on dark and \nmenacing',
#  ' buildings took on dark and \nmenacing as',
#  'ildings took on dark and \nmenacing aspec',
#  'ings took on dark and \nmenacing aspects.',
#  's took on dark and \nmenacing aspects. i ',
#  'ook on dark and \nmenacing aspects. i pul',
#  ' on dark and \nmenacing aspects. i pulled',
#  ' dark and \nmenacing aspects. i pulled my',
#  'rk and \nmenacing aspects. i pulled my co',
#  'and \nmenacing aspects. i pulled my coat ',
#  ' \nmenacing aspects. i pulled my coat tig',
#  'enacing aspects. i pulled my coat tightl',
#  'cing aspects. i pulled my coat tightly a',
#  'g aspects. i pulled my coat tightly arou',
#  'spects. i pulled my coat tightly around ',
#  'cts. i pulled my coat tightly around me ',
#  '. i pulled my coat tightly around me and',
#  ' pulled my coat tightly around me and hu',
#  'lled my coat tightly around me and hurri',
#  'd my coat tightly around me and hurried ',
#  'y coat tightly around me and hurried \nlu',
#  'oat tightly around me and hurried \nlurch',
#  ' tightly around me and hurried \nlurching',
#  'ghtly around me and hurried \nlurching do',
#  'ly around me and hurried \nlurching down ',
#  'around me and hurried \nlurching down the',
#  'und me and hurried \nlurching down the st',
#  ' me and hurried \nlurching down the stree',
#  ' and hurried \nlurching down the street, ',
#  'd hurried \nlurching down the street, whi',
#  'urried \nlurching down the street, whippe',
#  'ied \nlurching down the street, whipped b',
#  ' \nlurching down the street, whipped by a',
#  'urching down the street, whipped by a su',
#  'hing down the street, whipped by a sudde',
#  'g down the street, whipped by a sudden g',
#  'own the street, whipped by a sudden gust',
#  ' the street, whipped by a sudden gusting',
#  'e street, whipped by a sudden gusting wi',
#  'treet, whipped by a sudden gusting wind.',
#  'et, whipped by a sudden gusting wind. i ',
#  ' whipped by a sudden gusting wind. i \nbu',
#  'ipped by a sudden gusting wind. i \nbumpe',
#  'ed by a sudden gusting wind. i \nbumped i',
#  'by a sudden gusting wind. i \nbumped into',
#  'a sudden gusting wind. i \nbumped into so',
#  'udden gusting wind. i \nbumped into someo',
#  'en gusting wind. i \nbumped into someone ',
#  'gusting wind. i \nbumped into someone and',
#  'ting wind. i \nbumped into someone and st',
#  'g wind. i \nbumped into someone and stamm',
#  'ind. i \nbumped into someone and stammere',
#  '. i \nbumped into someone and stammered a',
#  ' \nbumped into someone and stammered an a',
#  'umped into someone and stammered an apol',
#  'ed into someone and stammered an apology',
#  'into someone and stammered an apology, b',
#  'o someone and stammered an apology, but ',
#  'omeone and stammered an apology, but he ',
#  'one and stammered an apology, but he was',
#  ...]

# %%
next_chars
# Out:
# ['h',
#  'k',
#  "'",
#  'g',
#  'd',
#  ' ',
#  '\n',
#  'm',
#  'e',
#  ' ',
#  'u',
#  'b',
#  'd',
#  'd',
#  '\n',
#  ' ',
#  'o',
#  'e',
#  's',
#  ' ',
#  '\n',
#  'i',
#  'r',
#  'u',
#  'i',
#  ':',
#  ' ',
#  'i',
#  ' ',
#  ' ',
#  'e',
#  'u',
#  'e',
#  '\n',
#  'e',
#  'i',
#  'h',
#  'k',
#  "'",
#  'g',
#  'd',
#  't',
#  't',
#  ' ',
#  'l',
#  'y',
#  '\n',
#  'e',
#  'e',
#  'a',
#  'a',
#  ' ',
#  ' ',
#  'e',
#  'n',
#  'o',
#  't',
#  ' ',
#  'i',
#  'r',
#  ' ',
#  'l',
#  'e',
#  't',
#  ' ',
#  'i',
#  'r',
#  ' ',
#  'd',
#  'v',
#  'y',
#  'i',
#  ' ',
#  's',
#  'l',
#  'g',
#  'a',
#  ' ',
#  'a',
#  's',
#  'o',
#  'a',
#  ' ',
#  'e',
#  'i',
#  ' ',
#  'y',
#  'n',
#  'z',
#  'h',
#  ' ',
#  'a',
#  ' ',
#  ' ',
#  'f',
#  ' ',
#  'o',
#  'l',
#  'h',
#  'm',
#  's',
#  ' ',
#  'o',
#  'n',
#  'e',
#  ' ',
#  '\n',
#  ' ',
#  't',
#  'd',
#  't',
#  'n',
#  'a',
#  'u',
#  'e',
#  'o',
#  't',
#  ' ',
#  'i',
#  ' ',
#  '\n',
#  'm',
#  'u',
#  'e',
#  'f',
#  ' ',
#  'm',
#  'k',
#  'f',
#  'm',
#  'h',
#  'a',
#  'h',
#  ' ',
#  ' ',
#  'h',
#  'h',
#  't',
#  'y',
#  'f',
#  'h',
#  'h',
#  'c',
#  'i',
#  'r',
#  ' ',
#  'i',
#  ' ',
#  ' ',
#  'e',
#  'a',
#  'x',
#  'i',
#  'n',
#  ' ',
#  ' ',
#  'o',
#  'l',
#  'a',
#  'd',
#  'h',
#  ' ',
#  'e',
#  ' ',
#  'm',
#  'i',
#  'e',
#  ' ',
#  ' ',
#  'c',
#  't',
#  'd',
#  't',
#  'y',
#  'l',
#  ' ',
#  'd',
#  'h',
#  'e',
#  'r',
#  'i',
#  'o',
#  'e',
#  'i',
#  'r',
#  'h',
#  'i',
#  ' ',
#  's',
#  'o',
#  'd',
#  's',
#  't',
#  ' ',
#  'b',
#  'c',
#  'i',
#  ' ',
#  ' ',
#  'i',
#  'o',
#  'i',
#  's',
#  'e',
#  't',
#  'n',
#  'e',
#  'e',
#  'l',
#  'e',
#  ' ',
#  'o',
#  'o',
#  'o',
#  'u',
#  't',
#  't',
#  's',
#  ' ',
#  'e',
#  'e',
#  'r',
#  's',
#  'a',
#  'h',
#  '\xca',
#  'o',
#  '\n',
#  ' ',
#  'a',
#  ' ',
#  'r',
#  'y',
#  'r',
#  'k',
#  '.',
#  'n',
#  'h',
#  'g',
#  'h',
#  ' ',
#  ' ',
#  't',
#  'o',
#  ' ',
#  'o',
#  ' ',
#  'r',
#  'i',
#  ' ',
#  ' ',
#  'r',
#  'a',
#  'i',
#  ' ',
#  'n',
#  'r',
#  'd',
#  'w',
#  'n',
#  'f',
#  ' ',
#  'o',
#  ' ',
#  't',
#  ' ',
#  'e',
#  'f',
#  ' ',
#  'e',
#  'i',
#  'e',
#  'i',
#  't',
#  'r',
#  'p',
#  ' ',
#  ' ',
#  'i',
#  ' ',
#  'w',
#  ' ',
#  'i',
#  ' ',
#  'u',
#  ' ',
#  ' ',
#  '\n',
#  'e',
#  ' ',
#  ' ',
#  'n',
#  'r',
#  'k',
#  'a',
#  't',
#  'a',
#  'i',
#  '1',
#  '1',
#  'n',
#  ' ',
#  'r',
#  'c',
#  'a',
#  'y',
#  'r',
#  'k',
#  'j',
#  't',
#  'h',
#  '\n',
#  'r',
#  'o',
#  'd',
#  'n',
#  'y',
#  ' ',
#  't',
#  'h',
#  ' ',
#  'u',
#  'a',
#  ' ',
#  'c',
#  'p',
#  ' ',
#  ' ',
#  'i',
#  ' ',
#  '\xb6',
#  'e',
#  ' ',
#  't',
#  ' ',
#  'o',
#  'h',
#  'i',
#  ' ',
#  't',
#  ' ',
#  'r',
#  'w',
#  'd',
#  's',
#  't',
#  'i',
#  't',
#  'o',
#  'a',
#  'o',
#  't',
#  'f',
#  'e',
#  'g',
#  ' ',
#  'e',
#  'i',
#  's',
#  'h',
#  'c',
#  'i',
#  'r',
#  'w',
#  'a',
#  ' ',
#  'l',
#  'n',
#  'o',
#  'a',
#  'i',
#  ' ',
#  'a',
#  'l',
#  'y',
#  'o',
#  't',
#  'd',
#  'p',
#  ' ',
#  ' ',
#  's',
#  'r',
#  'e',
#  'n',
#  'w',
#  'h',
#  ' ',
#  'p',
#  'o',
#  't',
#  ' ',
#  't',
#  ' ',
#  'k',
#  ' ',
#  'g',
#  'd',
#  't',
#  'e',
#  'o',
#  ' ',
#  ' ',
#  'e',
#  'w',
#  's',
#  ' ',
#  'v',
#  'y',
#  'a',
#  'e',
#  'd',
#  'o',
#  ' ',
#  'a',
#  'i',
#  'a',
#  'b',
#  'r',
#  'e',
#  'f',
#  'm',
#  'o',
#  'o',
#  '.',
#  'i',
#  'f',
#  't',
#  's',
#  'c',
#  't',
#  's',
#  'a',
#  '1',
#  '1',
#  'n',
#  'i',
#  't',
#  'l',
#  'a',
#  ' ',
#  'e',
#  'o',
#  ',',
#  't',
#  'u',
#  ' ',
#  'u',
#  ' ',
#  ' ',
#  't',
#  'e',
#  'b',
#  'n',
#  '.',
#  ' ',
#  'd',
#  't',
#  'a',
#  ' ',
#  'c',
#  'y',
#  'f',
#  'u',
#  'p',
#  'o',
#  'f',
#  'e',
#  'o',
#  'a',
#  ' ',
#  'd',
#  ' ',
#  's',
#  'i',
#  't',
#  'n',
#  'a',
#  ' ',
#  'c',
#  's',
#  'i',
#  'a',
#  "'",
#  'i',
#  't',
#  't',
#  'i',
#  'n',
#  'a',
#  'l',
#  'g',
#  '.',
#  '\n',
#  'g',
#  ' ',
#  's',
#  'e',
#  'n',
#  'n',
#  't',
#  'f',
#  'l',
#  'n',
#  'y',
#  'i',
#  'd',
#  's',
#  't',
#  'p',
#  ' ',
#  'z',
#  'y',
#  'n',
#  'r',
#  'a',
#  ' ',
#  'e',
#  'i',
#  'a',
#  'w',
#  'd',
#  'i',
#  ' ',
#  'e',
#  ' ',
#  'c',
#  'l',
#  'g',
#  't',
#  't',
#  'a',
#  'c',
#  'a',
#  'r',
#  'h',
#  ' ',
#  'n',
#  'b',
#  'c',
#  ' ',
#  'v',
#  'v',
#  ' ',
#  's',
#  'a',
#  ' ',
#  'd',
#  't',
#  'o',
#  'h',
#  's',
#  't',
#  'f',
#  'h',
#  'g',
#  't',
#  'm',
#  't',
#  't',
#  'i',
#  's',
#  'u',
#  ' ',
#  'd',
#  'o',
#  ' ',
#  ' ',
#  ' ',
#  'a',
#  'a',
#  'e',
#  'o',
#  '.',
#  'h',
#  ' ',
#  'd',
#  'a',
#  'e',
#  'd',
#  'a',
#  '\n',
#  'i',
#  ' ',
#  'h',
#  ' ',
#  'e',
#  'w',
#  'k',
#  'g',
#  'h',
#  'u',
#  ' ',
#  'e',
#  'o',
#  ' ',
#  'y',
#  'g',
#  'o',
#  'i',
#  ' ',
#  'p',
#  't',
#  'u',
#  'r',
#  'a',
#  'r',
#  's',
#  'a',
#  ' ',
#  'i',
#  ' ',
#  'o',
#  'u',
#  'l',
#  'l',
#  't',
#  ' ',
#  'o',
#  'e',
#  't',
#  'a',
#  ' ',
#  'r',
#  'i',
#  'c',
#  'o',
#  ' ',
#  'r',
#  ' ',
#  'm',
#  ' ',
#  ' ',
#  'e',
#  't',
#  'e',
#  ' ',
#  'k',
#  'w',
#  'h',
#  ' ',
#  'g',
#  'n',
#  ' ',
#  ' ',
#  's',
#  'b',
#  'a',
#  'e',
#  ' ',
#  'n',
#  ' ',
#  'p',
#  'k',
#  'e',
#  'a',
#  ' ',
#  't',
#  ' ',
#  's',
#  't',
#  'l',
#  'u',
#  'r',
#  'e',
#  't',
#  'd',
#  'c',
#  'e',
#  'j',
#  't',
#  'o',
#  'm',
#  'h',
#  'd',
#  'f',
#  'u',
#  'y',
#  ' ',
#  's',
#  'a',
#  'n',
#  'c',
#  'm',
#  'i',
#  't',
#  'g',
#  'i',
#  ' ',
#  'i',
#  'p',
#  't',
#  'u',
#  'r',
#  'a',
#  ' ',
#  'r',
#  'u',
#  'l',
#  't',
#  ' ',
#  'u',
#  ' ',
#  'w',
#  'd',
#  'n',
#  'e',
#  's',
#  'e',
#  't',
#  'g',
#  'e',
#  'i',
#  'v',
#  'n',
#  'o',
#  'u',
#  'e',
#  't',
#  'd',
#  'a',
#  ' ',
#  'h',
#  ' ',
#  'a',
#  'o',
#  'a',
#  ' ',
#  'e',
#  'e',
#  'l',
#  'i',
#  'i',
#  's',
#  'u',
#  ' ',
#  'c',
#  'l',
#  'h',
#  'e',
#  's',
#  'p',
#  'd',
#  'o',
#  's',
#  ' ',
#  'e',
#  'n',
#  'i',
#  'a',
#  'p',
#  'k',
#  ' ',
#  'd',
#  'o',
#  's',
#  'a',
#  'e',
#  'l',
#  'h',
#  'd',
#  ' ',
#  't',
#  's',
#  'a',
#  'f',
#  'n',
#  ' ',
#  'd',
#  'a',
#  'a',
#  'o',
#  'e',
#  ' ',
#  'd',
#  'u',
#  '.',
#  'i',
#  ' ',
#  's',
#  'i',
#  ' ',
#  ' ',
#  'n',
#  'r',
#  'y',
#  'a',
#  'l',
#  'e',
#  'c',
#  'a',
#  ' ',
#  'v',
#  'e',
#  's',
#  'i',
#  'i',
#  'n',
#  'n',
#  'e',
#  'm',
#  'e',
#  ',',
#  'n',
#  'a',
#  'e',
#  'm',
#  'u',
#  's',
#  'a',
#  'r',
#  'o',
#  'a',
#  't',
#  'r',
#  't',
#  'e',
#  ' ',
#  's',
#  'p',
#  'd',
#  'n',
#  'a',
#  'e',
#  'a',
#  't',
#  'r',
#  'a',
#  '\n',
#  'o',
#  'l',
#  ' ',
#  'r',
#  'd',
#  'u',
#  't',
#  'b',
#  'd',
#  'f',
#  'n',
#  'd',
#  'b',
#  'w',
#  'c',
#  'w',
#  ' ',
#  'e',
#  'i',
#  'o',
#  'h',
#  '\n',
#  'e',
#  'e',
#  's',
#  ' ',
#  ' ',
#  'n',
#  'r',
#  ' ',
#  'c',
#  'o',
#  'o',
#  'h',
#  's',
#  'e',
#  '.',
#  ' ',
#  'i',
#  ' ',
#  'a',
#  '.',
#  '\n',
#  'e',
#  't',
#  ' ',
#  'i',
#  ' ',
#  'n',
#  ' ',
#  'o',
#  ' ',
#  ' ',
#  'r',
#  'd',
#  'u',
#  't',
#  'b',
#  'd',
#  'f',
#  'n',
#  'd',
#  'b',
#  'a',
#  ' ',
#  's',
#  'b',
#  'n',
#  'i',
#  'e',
#  'n',
#  'o',
#  'e',
#  ' ',
#  't',
#  'r',
#  'l',
#  'w',
#  'g',
#  ' ',
#  't',
#  'i',
#  ' ',
#  ' ',
#  ' ',
#  'h',
#  'l',
#  'r',
#  ' ',
#  'e',
#  'v',
#  ' ',
#  'l',
#  'k',
#  ' ',
#  'e',
#  'r',
#  's',
#  'n',
#  'b',
#  'l',
#  'n',
#  ' ',
#  'o',
#  'o',
#  'd',
#  'k',
#  'n',
#  '\n',
#  'n',
#  'i',
#  ' ',
#  'p',
#  't',
#  ' ',
#  'p',
#  'l',
#  ' ',
#  ' ',
#  'a',
#  't',
#  'h',
#  'y',
#  'r',
#  'n',
#  'm',
#  'a',
#  ' ',
#  'r',
#  'e',
#  '\n',
#  'r',
#  'i',
#  ' ',
#  'w',
#  't',
#  ' ',
#  'r',
#  't',
#  'w',
#  'p',
#  'd',
#  'y',
#  ' ',
#  'd',
#  'n',
#  'u',
#  'i',
#  ' ',
#  'n',
#  ' ',
#  '\n',
#  'm',
#  'd',
#  'n',
#  ' ',
#  'm',
#  'n',
#  'a',
#  ' ',
#  'a',
#  'e',
#  'd',
#  'n',
#  'p',
#  'o',
#  ',',
#  'u',
#  'h',
#  'w',
#  ' ',
#  ...]

# %%
X = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)

# %%
X
# Out:
# array([[[False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         ...,
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False]],
#
#        [[False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         ...,
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False]],
#
#        [[False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         ...,
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False]],
#
#        ...,
#        [[False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         ...,
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False]],
#
#        [[False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         ...,
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False]],
#
#        [[False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         ...,
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False]]], dtype=bool)

# %%
list(enumerate(sentences))
# Out:
# [(0, ' \n \ndouglas adams  \n \nthe ultimate \nhitc'),
#  (1, '\ndouglas adams  \n \nthe ultimate \nhitchhi'),
#  (2, 'uglas adams  \n \nthe ultimate \nhitchhiker'),
#  (3, "as adams  \n \nthe ultimate \nhitchhiker's "),
#  (4, "adams  \n \nthe ultimate \nhitchhiker's gui"),
#  (5, "ms  \n \nthe ultimate \nhitchhiker's guide "),
#  (6, " \n \nthe ultimate \nhitchhiker's guide  \n "),
#  (7, "\nthe ultimate \nhitchhiker's guide  \n \nco"),
#  (8, "e ultimate \nhitchhiker's guide  \n \ncompl"),
#  (9, "ltimate \nhitchhiker's guide  \n \ncomplete"),
#  (10, "mate \nhitchhiker's guide  \n \ncomplete & "),
#  (11, "e \nhitchhiker's guide  \n \ncomplete & una"),
#  (12, "hitchhiker's guide  \n \ncomplete & unabri"),
#  (13, "chhiker's guide  \n \ncomplete & unabridge"),
#  (14, "iker's guide  \n \ncomplete & unabridged  "),
#  (15, "r's guide  \n \ncomplete & unabridged  \n \n"),
#  (16, ' guide  \n \ncomplete & unabridged  \n \n \nc'),
#  (17, 'ide  \n \ncomplete & unabridged  \n \n \ncont'),
#  (18, '  \n \ncomplete & unabridged  \n \n \ncontent'),
#  (19, ' \ncomplete & unabridged  \n \n \ncontents: '),
#  (20, 'omplete & unabridged  \n \n \ncontents:  \n '),
#  (21, 'lete & unabridged  \n \n \ncontents:  \n \n \n'),
#  (22, 'e & unabridged  \n \n \ncontents:  \n \n \nint'),
#  (23, ' unabridged  \n \n \ncontents:  \n \n \nintrod'),
#  (24, 'abridged  \n \n \ncontents:  \n \n \nintroduct'),
#  (25, 'idged  \n \n \ncontents:  \n \n \nintroduction'),
#  (26, 'ed  \n \n \ncontents:  \n \n \nintroduction: a'),
#  (27, ' \n \n \ncontents:  \n \n \nintroduction: a gu'),
#  (28, '\n \ncontents:  \n \n \nintroduction: a guide'),
#  (29, 'contents:  \n \n \nintroduction: a guide to'),
#  (30, 'tents:  \n \n \nintroduction: a guide to th'),
#  (31, 'ts:  \n \n \nintroduction: a guide to the g'),
#  (32, '  \n \n \nintroduction: a guide to the guid'),
#  (33, ' \n \nintroduction: a guide to the guide  '),
#  (34, '\nintroduction: a guide to the guide  \nth'),
#  (35, 'troduction: a guide to the guide  \nthe h'),
#  (36, 'duction: a guide to the guide  \nthe hitc'),
#  (37, 'tion: a guide to the guide  \nthe hitchhi'),
#  (38, 'n: a guide to the guide  \nthe hitchhiker'),
#  (39, "a guide to the guide  \nthe hitchhiker's "),
#  (40, "uide to the guide  \nthe hitchhiker's gui"),
#  (41, "e to the guide  \nthe hitchhiker's guide "),
#  (42, "o the guide  \nthe hitchhiker's guide to "),
#  (43, "he guide  \nthe hitchhiker's guide to the"),
#  (44, "guide  \nthe hitchhiker's guide to the ga"),
#  (45, "de  \nthe hitchhiker's guide to the galax"),
#  (46, " \nthe hitchhiker's guide to the galaxy  "),
#  (47, "he hitchhiker's guide to the galaxy  \nth"),
#  (48, "hitchhiker's guide to the galaxy  \nthe r"),
#  (49, "chhiker's guide to the galaxy  \nthe rest"),
#  (50, "iker's guide to the galaxy  \nthe restaur"),
#  (51, "r's guide to the galaxy  \nthe restaurant"),
#  (52, ' guide to the galaxy  \nthe restaurant at'),
#  (53, 'ide to the galaxy  \nthe restaurant at th'),
#  (54, ' to the galaxy  \nthe restaurant at the e'),
#  (55, ' the galaxy  \nthe restaurant at the end '),
#  (56, 'e galaxy  \nthe restaurant at the end of '),
#  (57, 'alaxy  \nthe restaurant at the end of the'),
#  (58, 'xy  \nthe restaurant at the end of the un'),
#  (59, ' \nthe restaurant at the end of the unive'),
#  (60, 'he restaurant at the end of the universe'),
#  (61, 'restaurant at the end of the universe  \n'),
#  (62, 'taurant at the end of the universe  \nlif'),
#  (63, 'rant at the end of the universe  \nlife, '),
#  (64, 't at the end of the universe  \nlife, the'),
#  (65, 't the end of the universe  \nlife, the un'),
#  (66, 'he end of the universe  \nlife, the unive'),
#  (67, 'end of the universe  \nlife, the universe'),
#  (68, ' of the universe  \nlife, the universe an'),
#  (69, ' the universe  \nlife, the universe and e'),
#  (70, 'e universe  \nlife, the universe and ever'),
#  (71, 'niverse  \nlife, the universe and everyth'),
#  (72, 'erse  \nlife, the universe and everything'),
#  (73, 'e  \nlife, the universe and everything  \n'),
#  (74, '\nlife, the universe and everything  \nso '),
#  (75, 'fe, the universe and everything  \nso lon'),
#  (76, ' the universe and everything  \nso long, '),
#  (77, 'e universe and everything  \nso long, and'),
#  (78, 'niverse and everything  \nso long, and th'),
#  (79, 'erse and everything  \nso long, and thank'),
#  (80, 'e and everything  \nso long, and thanks f'),
#  (81, 'nd everything  \nso long, and thanks for '),
#  (82, 'everything  \nso long, and thanks for all'),
#  (83, 'rything  \nso long, and thanks for all th'),
#  (84, 'hing  \nso long, and thanks for all the f'),
#  (85, 'g  \nso long, and thanks for all the fish'),
#  (86, '\nso long, and thanks for all the fish  \n'),
#  (87, ' long, and thanks for all the fish  \nyou'),
#  (88, 'ng, and thanks for all the fish  \nyoung '),
#  (89, ' and thanks for all the fish  \nyoung zap'),
#  (90, 'd thanks for all the fish  \nyoung zaphod'),
#  (91, 'hanks for all the fish  \nyoung zaphod pl'),
#  (92, 'ks for all the fish  \nyoung zaphod plays'),
#  (93, 'for all the fish  \nyoung zaphod plays it'),
#  (94, ' all the fish  \nyoung zaphod plays it sa'),
#  (95, 'l the fish  \nyoung zaphod plays it safe '),
#  (96, 'he fish  \nyoung zaphod plays it safe  \nm'),
#  (97, 'fish  \nyoung zaphod plays it safe  \nmost'),
#  (98, 'h  \nyoung zaphod plays it safe  \nmostly '),
#  (99, '\nyoung zaphod plays it safe  \nmostly har'),
#  (100, 'ung zaphod plays it safe  \nmostly harmle'),
#  (101, ' zaphod plays it safe  \nmostly harmless '),
#  (102, 'phod plays it safe  \nmostly harmless  \nf'),
#  (103, 'd plays it safe  \nmostly harmless  \nfoot'),
#  (104, 'lays it safe  \nmostly harmless  \nfootnot'),
#  (105, 's it safe  \nmostly harmless  \nfootnotes '),
#  (106, 't safe  \nmostly harmless  \nfootnotes  \n '),
#  (107, 'afe  \nmostly harmless  \nfootnotes  \n \n \n'),
#  (108, '  \nmostly harmless  \nfootnotes  \n \n \n in'),
#  (109, 'mostly harmless  \nfootnotes  \n \n \n intro'),
#  (110, 'tly harmless  \nfootnotes  \n \n \n introduc'),
#  (111, ' harmless  \nfootnotes  \n \n \n introductio'),
#  (112, 'rmless  \nfootnotes  \n \n \n introduction: '),
#  (113, 'ess  \nfootnotes  \n \n \n introduction: a g'),
#  (114, '  \nfootnotes  \n \n \n introduction: a guid'),
#  (115, 'footnotes  \n \n \n introduction: a guide t'),
#  (116, 'tnotes  \n \n \n introduction: a guide to \n'),
#  (117, 'tes  \n \n \n introduction: a guide to \nthe'),
#  (118, '  \n \n \n introduction: a guide to \nthe gu'),
#  (119, ' \n \n introduction: a guide to \nthe guide'),
#  (120, '\n introduction: a guide to \nthe guide \n '),
#  (121, 'ntroduction: a guide to \nthe guide \n \nso'),
#  (122, 'oduction: a guide to \nthe guide \n \nsome '),
#  (123, 'ction: a guide to \nthe guide \n \nsome unh'),
#  (124, 'on: a guide to \nthe guide \n \nsome unhelp'),
#  (125, ' a guide to \nthe guide \n \nsome unhelpful'),
#  (126, 'guide to \nthe guide \n \nsome unhelpful re'),
#  (127, 'de to \nthe guide \n \nsome unhelpful remar'),
#  (128, 'to \nthe guide \n \nsome unhelpful remarks '),
#  (129, '\nthe guide \n \nsome unhelpful remarks fro'),
#  (130, 'e guide \n \nsome unhelpful remarks from t'),
#  (131, 'uide \n \nsome unhelpful remarks from the '),
#  (132, 'e \n \nsome unhelpful remarks from the aut'),
#  (133, ' \nsome unhelpful remarks from the author'),
#  (134, 'ome unhelpful remarks from the author  \n'),
#  (135, ' unhelpful remarks from the author  \n \nt'),
#  (136, 'helpful remarks from the author  \n \nthe '),
#  (137, 'pful remarks from the author  \n \nthe his'),
#  (138, 'l remarks from the author  \n \nthe histor'),
#  (139, 'emarks from the author  \n \nthe history o'),
#  (140, 'rks from the author  \n \nthe history of t'),
#  (141, ' from the author  \n \nthe history of the '),
#  (142, 'om the author  \n \nthe history of the hit'),
#  (143, 'the author  \n \nthe history of the hitchh'),
#  (144, ' author  \n \nthe history of the hitchhike'),
#  (145, "thor  \n \nthe history of the hitchhiker's"),
#  (146, "r  \n \nthe history of the hitchhiker's gu"),
#  (147, "\n \nthe history of the hitchhiker's guide"),
#  (148, "the history of the hitchhiker's guide to"),
#  (149, " history of the hitchhiker's guide to th"),
#  (150, "story of the hitchhiker's guide to the g"),
#  (151, "ry of the hitchhiker's guide to the gala"),
#  (152, "of the hitchhiker's guide to the galaxy "),
#  (153, "the hitchhiker's guide to the galaxy is "),
#  (154, " hitchhiker's guide to the galaxy is now"),
#  (155, "tchhiker's guide to the galaxy is now so"),
#  (156, "hiker's guide to the galaxy is now so \nc"),
#  (157, "er's guide to the galaxy is now so \ncomp"),
#  (158, 's guide to the galaxy is now so \ncomplic'),
#  (159, 'uide to the galaxy is now so \ncomplicate'),
#  (160, 'e to the galaxy is now so \ncomplicated t'),
#  (161, 'o the galaxy is now so \ncomplicated that'),
#  (162, 'he galaxy is now so \ncomplicated that ev'),
#  (163, 'galaxy is now so \ncomplicated that every'),
#  (164, 'axy is now so \ncomplicated that every ti'),
#  (165, ' is now so \ncomplicated that every time '),
#  (166, ' now so \ncomplicated that every time i t'),
#  (167, 'w so \ncomplicated that every time i tell'),
#  (168, 'o \ncomplicated that every time i tell it'),
#  (169, 'complicated that every time i tell it i '),
#  (170, 'plicated that every time i tell it i con'),
#  (171, 'cated that every time i tell it i contra'),
#  (172, 'ed that every time i tell it i contradic'),
#  (173, 'that every time i tell it i contradict m'),
#  (174, 't every time i tell it i contradict myse'),
#  (175, 'very time i tell it i contradict myself,'),
#  (176, 'y time i tell it i contradict myself, an'),
#  (177, 'ime i tell it i contradict myself, and w'),
#  (178, ' i tell it i contradict myself, and when'),
#  (179, 'tell it i contradict myself, and wheneve'),
#  (180, 'l it i contradict myself, and whenever \n'),
#  (181, 't i contradict myself, and whenever \ni d'),
#  (182, ' contradict myself, and whenever \ni do g'),
#  (183, 'ntradict myself, and whenever \ni do get '),
#  (184, 'adict myself, and whenever \ni do get it '),
#  (185, 'ct myself, and whenever \ni do get it rig'),
#  (186, 'myself, and whenever \ni do get it right '),
#  (187, "elf, and whenever \ni do get it right i'm"),
#  (188, ", and whenever \ni do get it right i'm mi"),
#  (189, "nd whenever \ni do get it right i'm misqu"),
#  (190, "whenever \ni do get it right i'm misquote"),
#  (191, "never \ni do get it right i'm misquoted. "),
#  (192, "er \ni do get it right i'm misquoted. so "),
#  (193, "\ni do get it right i'm misquoted. so the"),
#  (194, "do get it right i'm misquoted. so the pu"),
#  (195, "get it right i'm misquoted. so the publi"),
#  (196, " it right i'm misquoted. so the publicat"),
#  (197, " right i'm misquoted. so the publication"),
#  (198, "ght i'm misquoted. so the publication of"),
#  (199, " i'm misquoted. so the publication of th"),
#  (200, 'm misquoted. so the publication of this '),
#  (201, 'isquoted. so the publication of this omn'),
#  (202, 'uoted. so the publication of this omnibu'),
#  (203, 'ed. so the publication of this omnibus \n'),
#  (204, ' so the publication of this omnibus \nedi'),
#  (205, ' the publication of this omnibus \neditio'),
#  (206, 'e publication of this omnibus \nedition s'),
#  (207, 'ublication of this omnibus \nedition seem'),
#  (208, 'ication of this omnibus \nedition seemed '),
#  (209, 'tion of this omnibus \nedition seemed lik'),
#  (210, 'n of this omnibus \nedition seemed like a'),
#  (211, 'f this omnibus \nedition seemed like a go'),
#  (212, 'his omnibus \nedition seemed like a good '),
#  (213, ' omnibus \nedition seemed like a good opp'),
#  (214, 'nibus \nedition seemed like a good opport'),
#  (215, 'us \nedition seemed like a good opportuni'),
#  (216, '\nedition seemed like a good opportunity '),
#  (217, 'ition seemed like a good opportunity to '),
#  (218, 'on seemed like a good opportunity to set'),
#  (219, 'seemed like a good opportunity to set th'),
#  (220, 'med like a good opportunity to set the r'),
#  (221, ' like a good opportunity to set the reco'),
#  (222, 'ke a good opportunity to set the record '),
#  (223, 'a good opportunity to set the record str'),
#  (224, 'ood opportunity to set the record straig'),
#  (225, ' opportunity to set the record straight '),
#  (226, 'portunity to set the record straight \xca\xb9 '),
#  (227, 'tunity to set the record straight \xca\xb9 or '),
#  (228, 'ity to set the record straight \xca\xb9 or \nat'),
#  (229, ' to set the record straight \xca\xb9 or \nat le'),
#  (230, ' set the record straight \xca\xb9 or \nat least'),
#  (231, 't the record straight \xca\xb9 or \nat least fi'),
#  (232, 'he record straight \xca\xb9 or \nat least firml'),
#  (233, 'record straight \xca\xb9 or \nat least firmly c'),
#  (234, 'ord straight \xca\xb9 or \nat least firmly croo'),
#  (235, ' straight \xca\xb9 or \nat least firmly crooked'),
#  (236, 'raight \xca\xb9 or \nat least firmly crooked. a'),
#  (237, 'ght \xca\xb9 or \nat least firmly crooked. anyt'),
#  (238, ' \xca\xb9 or \nat least firmly crooked. anythin'),
#  (239, ' or \nat least firmly crooked. anything t'),
#  (240, ' \nat least firmly crooked. anything that'),
#  (241, 't least firmly crooked. anything that is'),
#  (242, 'east firmly crooked. anything that is pu'),
#  (243, 't firmly crooked. anything that is put d'),
#  (244, 'irmly crooked. anything that is put down'),
#  (245, 'ly crooked. anything that is put down wr'),
#  (246, 'crooked. anything that is put down wrong'),
#  (247, 'oked. anything that is put down wrong he'),
#  (248, 'd. anything that is put down wrong here '),
#  (249, 'anything that is put down wrong here is,'),
#  (250, 'thing that is put down wrong here is, as'),
#  (251, 'ng that is put down wrong here is, as fa'),
#  (252, 'that is put down wrong here is, as far \n'),
#  (253, 't is put down wrong here is, as far \nas '),
#  (254, "s put down wrong here is, as far \nas i'm"),
#  (255, "ut down wrong here is, as far \nas i'm co"),
#  (256, "down wrong here is, as far \nas i'm conce"),
#  (257, "n wrong here is, as far \nas i'm concerne"),
#  (258, "rong here is, as far \nas i'm concerned, "),
#  (259, "g here is, as far \nas i'm concerned, wro"),
#  (260, "ere is, as far \nas i'm concerned, wrong "),
#  (261, " is, as far \nas i'm concerned, wrong for"),
#  (262, ", as far \nas i'm concerned, wrong for go"),
#  (263, "s far \nas i'm concerned, wrong for good."),
#  (264, "ar \nas i'm concerned, wrong for good.  \n"),
#  (265, "\nas i'm concerned, wrong for good.  \nthe"),
#  (266, " i'm concerned, wrong for good.  \nthe id"),
#  (267, 'm concerned, wrong for good.  \nthe idea '),
#  (268, 'oncerned, wrong for good.  \nthe idea for'),
#  (269, 'erned, wrong for good.  \nthe idea for th'),
#  (270, 'ed, wrong for good.  \nthe idea for the t'),
#  (271, ' wrong for good.  \nthe idea for the titl'),
#  (272, 'ong for good.  \nthe idea for the title f'),
#  (273, ' for good.  \nthe idea for the title firs'),
#  (274, 'r good.  \nthe idea for the title first c'),
#  (275, 'ood.  \nthe idea for the title first crop'),
#  (276, '.  \nthe idea for the title first cropped'),
#  (277, '\nthe idea for the title first cropped up'),
#  (278, 'e idea for the title first cropped up wh'),
#  (279, 'dea for the title first cropped up while'),
#  (280, ' for the title first cropped up while i '),
#  (281, 'r the title first cropped up while i was'),
#  (282, 'he title first cropped up while i was ly'),
#  (283, 'title first cropped up while i was lying'),
#  (284, 'le first cropped up while i was lying dr'),
#  (285, 'first cropped up while i was lying drunk'),
#  (286, 'st cropped up while i was lying drunk in'),
#  (287, 'cropped up while i was lying drunk in a '),
#  (288, 'pped up while i was lying drunk in a \nfi'),
#  (289, 'd up while i was lying drunk in a \nfield'),
#  (290, 'p while i was lying drunk in a \nfield in'),
#  (291, 'hile i was lying drunk in a \nfield in in'),
#  (292, 'e i was lying drunk in a \nfield in innsb'),
#  (293, ' was lying drunk in a \nfield in innsbruc'),
#  (294, 's lying drunk in a \nfield in innsbruck, '),
#  (295, 'ying drunk in a \nfield in innsbruck, aus'),
#  (296, 'g drunk in a \nfield in innsbruck, austri'),
#  (297, 'runk in a \nfield in innsbruck, austria, '),
#  (298, 'k in a \nfield in innsbruck, austria, in '),
#  (299, 'n a \nfield in innsbruck, austria, in 197'),
#  (300, ' \nfield in innsbruck, austria, in 1971. '),
#  (301, 'ield in innsbruck, austria, in 1971. not'),
#  (302, 'd in innsbruck, austria, in 1971. not pa'),
#  (303, 'n innsbruck, austria, in 1971. not parti'),
#  (304, 'nnsbruck, austria, in 1971. not particul'),
#  (305, 'bruck, austria, in 1971. not particularl'),
#  (306, 'ck, austria, in 1971. not particularly d'),
#  (307, ' austria, in 1971. not particularly drun'),
#  (308, 'stria, in 1971. not particularly drunk, '),
#  (309, 'ia, in 1971. not particularly drunk, jus'),
#  (310, ' in 1971. not particularly drunk, just t'),
#  (311, ' 1971. not particularly drunk, just the '),
#  (312, '71. not particularly drunk, just the \nso'),
#  (313, ' not particularly drunk, just the \nsort '),
#  (314, 't particularly drunk, just the \nsort of '),
#  (315, 'articularly drunk, just the \nsort of dru'),
#  (316, 'icularly drunk, just the \nsort of drunk '),
#  (317, 'larly drunk, just the \nsort of drunk you'),
#  (318, 'ly drunk, just the \nsort of drunk you ge'),
#  (319, 'drunk, just the \nsort of drunk you get w'),
#  (320, 'nk, just the \nsort of drunk you get when'),
#  (321, ' just the \nsort of drunk you get when yo'),
#  (322, 'st the \nsort of drunk you get when you h'),
#  (323, 'the \nsort of drunk you get when you have'),
#  (324, ' \nsort of drunk you get when you have a '),
#  (325, 'ort of drunk you get when you have a cou'),
#  (326, ' of drunk you get when you have a couple'),
#  (327, ' drunk you get when you have a couple of'),
#  (328, 'unk you get when you have a couple of st'),
#  (329, ' you get when you have a couple of stiff'),
#  (330, 'u get when you have a couple of stiff g\xc3'),
#  (331, 'et when you have a couple of stiff g\xc3\xb6ss'),
#  (332, 'when you have a couple of stiff g\xc3\xb6ssers'),
#  (333, 'n you have a couple of stiff g\xc3\xb6ssers af'),
#  (334, 'ou have a couple of stiff g\xc3\xb6ssers after'),
#  (335, 'have a couple of stiff g\xc3\xb6ssers after \nn'),
#  (336, 'e a couple of stiff g\xc3\xb6ssers after \nnot '),
#  (337, ' couple of stiff g\xc3\xb6ssers after \nnot hav'),
#  (338, 'uple of stiff g\xc3\xb6ssers after \nnot having'),
#  (339, 'e of stiff g\xc3\xb6ssers after \nnot having ea'),
#  (340, 'f stiff g\xc3\xb6ssers after \nnot having eaten'),
#  (341, 'tiff g\xc3\xb6ssers after \nnot having eaten fo'),
#  (342, 'f g\xc3\xb6ssers after \nnot having eaten for t'),
#  (343, '\xc3\xb6ssers after \nnot having eaten for two '),
#  (344, 'sers after \nnot having eaten for two day'),
#  (345, 's after \nnot having eaten for two days s'),
#  (346, 'fter \nnot having eaten for two days stra'),
#  (347, 'r \nnot having eaten for two days straigh'),
#  (348, 'not having eaten for two days straight, '),
#  (349, ' having eaten for two days straight, on '),
#  (350, 'ving eaten for two days straight, on acc'),
#  (351, 'g eaten for two days straight, on accoun'),
#  (352, 'aten for two days straight, on account o'),
#  (353, 'n for two days straight, on account of b'),
#  (354, 'or two days straight, on account of bein'),
#  (355, 'two days straight, on account of being a'),
#  (356, ' days straight, on account of being a \np'),
#  (357, 'ys straight, on account of being a \npenn'),
#  (358, 'straight, on account of being a \npennile'),
#  (359, 'aight, on account of being a \npenniless '),
#  (360, 'ht, on account of being a \npenniless hit'),
#  (361, ' on account of being a \npenniless hitchh'),
#  (362, ' account of being a \npenniless hitchhike'),
#  (363, 'count of being a \npenniless hitchhiker. '),
#  (364, 'nt of being a \npenniless hitchhiker. we '),
#  (365, 'of being a \npenniless hitchhiker. we are'),
#  (366, 'being a \npenniless hitchhiker. we are ta'),
#  (367, 'ng a \npenniless hitchhiker. we are talki'),
#  (368, 'a \npenniless hitchhiker. we are talking '),
#  (369, 'penniless hitchhiker. we are talking of '),
#  (370, 'niless hitchhiker. we are talking of a m'),
#  (371, 'ess hitchhiker. we are talking of a mild'),
#  (372, ' hitchhiker. we are talking of a mild in'),
#  (373, 'tchhiker. we are talking of a mild inabi'),
#  (374, 'hiker. we are talking of a mild inabilit'),
#  (375, 'er. we are talking of a mild inability t'),
#  (376, ' we are talking of a mild inability to s'),
#  (377, ' are talking of a mild inability to stan'),
#  (378, 'e talking of a mild inability to stand u'),
#  (379, 'alking of a mild inability to stand up. '),
#  (380, 'ing of a mild inability to stand up.  \ni'),
#  (381, ' of a mild inability to stand up.  \ni wa'),
#  (382, ' a mild inability to stand up.  \ni was t'),
#  (383, 'mild inability to stand up.  \ni was trav'),
#  (384, 'd inability to stand up.  \ni was traveli'),
#  (385, 'nability to stand up.  \ni was traveling '),
#  (386, 'ility to stand up.  \ni was traveling wit'),
#  (387, 'ty to stand up.  \ni was traveling with a'),
#  (388, 'to stand up.  \ni was traveling with a co'),
#  (389, 'stand up.  \ni was traveling with a copy '),
#  (390, 'nd up.  \ni was traveling with a copy of '),
#  (391, 'up.  \ni was traveling with a copy of the'),
#  (392, '  \ni was traveling with a copy of the hi'),
#  (393, 'i was traveling with a copy of the hitch'),
#  (394, 'as traveling with a copy of the hitch hi'),
#  (395, 'traveling with a copy of the hitch hiker'),
#  (396, 'veling with a copy of the hitch hiker s '),
#  (397, 'ing with a copy of the hitch hiker s gui'),
#  (398, ' with a copy of the hitch hiker s guide '),
#  (399, 'th a copy of the hitch hiker s guide to '),
#  (400, 'a copy of the hitch hiker s guide to eur'),
#  (401, 'opy of the hitch hiker s guide to europe'),
#  (402, ' of the hitch hiker s guide to europe by'),
#  (403, ' the hitch hiker s guide to europe by \nk'),
#  (404, 'e hitch hiker s guide to europe by \nken '),
#  (405, 'itch hiker s guide to europe by \nken wal'),
#  (406, 'h hiker s guide to europe by \nken walsh,'),
#  (407, 'iker s guide to europe by \nken walsh, a '),
#  (408, 'r s guide to europe by \nken walsh, a ver'),
#  (409, ' guide to europe by \nken walsh, a very b'),
#  (410, 'ide to europe by \nken walsh, a very batt'),
#  (411, ' to europe by \nken walsh, a very battere'),
#  (412, ' europe by \nken walsh, a very battered c'),
#  (413, 'rope by \nken walsh, a very battered copy'),
#  (414, 'e by \nken walsh, a very battered copy th'),
#  (415, 'y \nken walsh, a very battered copy that '),
#  (416, 'ken walsh, a very battered copy that i h'),
#  (417, ' walsh, a very battered copy that i had '),
#  (418, 'lsh, a very battered copy that i had bor'),
#  (419, ', a very battered copy that i had borrow'),
#  (420, ' very battered copy that i had borrowed '),
#  (421, 'ry battered copy that i had borrowed fro'),
#  (422, 'battered copy that i had borrowed from s'),
#  (423, 'tered copy that i had borrowed from some'),
#  (424, 'ed copy that i had borrowed from someone'),
#  (425, 'copy that i had borrowed from someone. \n'),
#  (426, 'y that i had borrowed from someone. \nin '),
#  (427, 'hat i had borrowed from someone. \nin fac'),
#  (428, ' i had borrowed from someone. \nin fact, '),
#  (429, 'had borrowed from someone. \nin fact, sin'),
#  (430, ' borrowed from someone. \nin fact, since '),
#  (431, 'rrowed from someone. \nin fact, since thi'),
#  (432, 'wed from someone. \nin fact, since this w'),
#  (433, ' from someone. \nin fact, since this was '),
#  (434, 'om someone. \nin fact, since this was 197'),
#  (435, 'someone. \nin fact, since this was 1971 a'),
#  (436, 'eone. \nin fact, since this was 1971 and '),
#  (437, 'e. \nin fact, since this was 1971 and i s'),
#  (438, '\nin fact, since this was 1971 and i stil'),
#  (439, ' fact, since this was 1971 and i still h'),
#  (440, 'ct, since this was 1971 and i still have'),
#  (441, ' since this was 1971 and i still have th'),
#  (442, 'nce this was 1971 and i still have the b'),
#  (443, ' this was 1971 and i still have the book'),
#  (444, 'is was 1971 and i still have the book, i'),
#  (445, 'was 1971 and i still have the book, it m'),
#  (446, ' 1971 and i still have the book, it must'),
#  (447, '71 and i still have the book, it must co'),
#  (448, 'and i still have the book, it must count'),
#  (449, ' i still have the book, it must count as'),
#  (450, 'still have the book, it must count as \ns'),
#  (451, 'll have the book, it must count as \nstol'),
#  (452, 'have the book, it must count as \nstolen '),
#  (453, 'e the book, it must count as \nstolen by '),
#  (454, 'he book, it must count as \nstolen by now'),
#  (455, 'book, it must count as \nstolen by now. i'),
#  (456, 'k, it must count as \nstolen by now. i di'),
#  (457, "it must count as \nstolen by now. i didn'"),
#  (458, "must count as \nstolen by now. i didn't h"),
#  (459, "t count as \nstolen by now. i didn't have"),
#  (460, "ount as \nstolen by now. i didn't have a "),
#  (461, "t as \nstolen by now. i didn't have a cop"),
#  (462, "s \nstolen by now. i didn't have a copy o"),
#  (463, "stolen by now. i didn't have a copy of e"),
#  (464, "len by now. i didn't have a copy of euro"),
#  (465, " by now. i didn't have a copy of europe "),
#  (466, " now. i didn't have a copy of europe on "),
#  (467, "w. i didn't have a copy of europe on fiv"),
#  (468, "i didn't have a copy of europe on five d"),
#  (469, "idn't have a copy of europe on five doll"),
#  (470, "'t have a copy of europe on five dollars"),
#  (471, 'have a copy of europe on five dollars a '),
#  (472, 'e a copy of europe on five dollars a day'),
#  (473, ' copy of europe on five dollars a day (a'),
#  (474, 'py of europe on five dollars a day (as \n'),
#  (475, 'of europe on five dollars a day (as \nit '),
#  (476, 'europe on five dollars a day (as \nit the'),
#  (477, 'ope on five dollars a day (as \nit then w'),
#  (478, ' on five dollars a day (as \nit then was)'),
#  (479, ' five dollars a day (as \nit then was) be'),
#  (480, 've dollars a day (as \nit then was) becau'),
#  (481, 'dollars a day (as \nit then was) because '),
#  (482, 'lars a day (as \nit then was) because i w'),
#  (483, 's a day (as \nit then was) because i wasn'),
#  (484, " day (as \nit then was) because i wasn't "),
#  (485, "y (as \nit then was) because i wasn't in "),
#  (486, "as \nit then was) because i wasn't in tha"),
#  (487, "\nit then was) because i wasn't in that f"),
#  (488, " then was) because i wasn't in that fina"),
#  (489, "en was) because i wasn't in that financi"),
#  (490, "was) because i wasn't in that financial "),
#  (491, ") because i wasn't in that financial lea"),
#  (492, "ecause i wasn't in that financial league"),
#  (493, "use i wasn't in that financial league.  "),
#  (494, " i wasn't in that financial league.  \nni"),
#  (495, "wasn't in that financial league.  \nnight"),
#  (496, "n't in that financial league.  \nnight wa"),
#  (497, ' in that financial league.  \nnight was b'),
#  (498, ' that financial league.  \nnight was begi'),
#  (499, 'at financial league.  \nnight was beginni'),
#  (500, 'financial league.  \nnight was beginning '),
#  (501, 'ancial league.  \nnight was beginning to '),
#  (502, 'ial league.  \nnight was beginning to fal'),
#  (503, ' league.  \nnight was beginning to fall o'),
#  (504, 'ague.  \nnight was beginning to fall on m'),
#  (505, 'e.  \nnight was beginning to fall on my f'),
#  (506, ' \nnight was beginning to fall on my fiel'),
#  (507, 'ight was beginning to fall on my field a'),
#  (508, 't was beginning to fall on my field as i'),
#  (509, 'as beginning to fall on my field as it s'),
#  (510, 'beginning to fall on my field as it spun'),
#  (511, 'inning to fall on my field as it spun la'),
#  (512, 'ing to fall on my field as it spun lazil'),
#  (513, ' to fall on my field as it spun lazily u'),
#  (514, ' fall on my field as it spun lazily unde'),
#  (515, 'll on my field as it spun lazily underne'),
#  (516, 'on my field as it spun lazily underneath'),
#  (517, 'my field as it spun lazily underneath \nm'),
#  (518, 'field as it spun lazily underneath \nme. '),
#  (519, 'ld as it spun lazily underneath \nme. i w'),
#  (520, 'as it spun lazily underneath \nme. i was '),
#  (521, 'it spun lazily underneath \nme. i was won'),
#  (522, 'spun lazily underneath \nme. i was wonder'),
#  (523, 'n lazily underneath \nme. i was wondering'),
#  (524, 'azily underneath \nme. i was wondering wh'),
#  (525, 'ly underneath \nme. i was wondering where'),
#  (526, 'underneath \nme. i was wondering where i '),
#  (527, 'erneath \nme. i was wondering where i cou'),
#  (528, 'eath \nme. i was wondering where i could '),
#  (529, 'h \nme. i was wondering where i could go '),
#  (530, 'me. i was wondering where i could go tha'),
#  (531, ' i was wondering where i could go that w'),
#  (532, 'was wondering where i could go that was '),
#  (533, ' wondering where i could go that was che'),
#  (534, 'ndering where i could go that was cheape'),
#  (535, 'ring where i could go that was cheaper t'),
#  (536, 'g where i could go that was cheaper than'),
#  (537, 'here i could go that was cheaper than \ni'),
#  (538, 'e i could go that was cheaper than \ninns'),
#  (539, ' could go that was cheaper than \ninnsbru'),
#  (540, 'uld go that was cheaper than \ninnsbruck,'),
#  (541, ' go that was cheaper than \ninnsbruck, re'),
#  (542, ' that was cheaper than \ninnsbruck, revol'),
#  (543, 'at was cheaper than \ninnsbruck, revolved'),
#  (544, 'was cheaper than \ninnsbruck, revolved le'),
#  (545, ' cheaper than \ninnsbruck, revolved less '),
#  (546, 'eaper than \ninnsbruck, revolved less and'),
#  (547, 'er than \ninnsbruck, revolved less and di'),
#  (548, "than \ninnsbruck, revolved less and didn'"),
#  (549, "n \ninnsbruck, revolved less and didn't d"),
#  (550, "innsbruck, revolved less and didn't do t"),
#  (551, "sbruck, revolved less and didn't do the "),
#  (552, "uck, revolved less and didn't do the sor"),
#  (553, ", revolved less and didn't do the sort o"),
#  (554, "evolved less and didn't do the sort of t"),
#  (555, "lved less and didn't do the sort of thin"),
#  (556, "d less and didn't do the sort of things "),
#  (557, "ess and didn't do the sort of things to "),
#  (558, " and didn't do the sort of things to me "),
#  (559, "d didn't do the sort of things to me tha"),
#  (560, "idn't do the sort of things to me that \n"),
#  (561, "'t do the sort of things to me that \ninn"),
#  (562, 'do the sort of things to me that \ninnsbr'),
#  (563, 'the sort of things to me that \ninnsbruck'),
#  (564, ' sort of things to me that \ninnsbruck ha'),
#  (565, 'rt of things to me that \ninnsbruck had d'),
#  (566, 'of things to me that \ninnsbruck had done'),
#  (567, 'things to me that \ninnsbruck had done to'),
#  (568, 'ngs to me that \ninnsbruck had done to me'),
#  (569, ' to me that \ninnsbruck had done to me th'),
#  (570, ' me that \ninnsbruck had done to me that '),
#  (571, ' that \ninnsbruck had done to me that aft'),
#  (572, 'at \ninnsbruck had done to me that aftern'),
#  (573, '\ninnsbruck had done to me that afternoon'),
#  (574, 'nsbruck had done to me that afternoon. w'),
#  (575, 'ruck had done to me that afternoon. what'),
#  (576, 'k had done to me that afternoon. what ha'),
#  (577, 'ad done to me that afternoon. what had h'),
#  (578, 'done to me that afternoon. what had happ'),
#  (579, 'e to me that afternoon. what had happene'),
#  (580, 'o me that afternoon. what had happened w'),
#  (581, 'e that afternoon. what had happened was '),
#  (582, 'hat afternoon. what had happened was \nth'),
#  (583, ' afternoon. what had happened was \nthis.'),
#  (584, 'ternoon. what had happened was \nthis. i '),
#  (585, 'noon. what had happened was \nthis. i had'),
#  (586, 'n. what had happened was \nthis. i had be'),
#  (587, 'what had happened was \nthis. i had been '),
#  (588, 't had happened was \nthis. i had been wal'),
#  (589, 'ad happened was \nthis. i had been walkin'),
#  (590, 'happened was \nthis. i had been walking t'),
#  (591, 'pened was \nthis. i had been walking thro'),
#  (592, 'ed was \nthis. i had been walking through'),
#  (593, 'was \nthis. i had been walking through th'),
#  (594, ' \nthis. i had been walking through the t'),
#  (595, 'his. i had been walking through the town'),
#  (596, '. i had been walking through the town tr'),
#  (597, ' had been walking through the town tryin'),
#  (598, 'd been walking through the town trying t'),
#  (599, 'een walking through the town trying to f'),
#  (600, ' walking through the town trying to find'),
#  (601, 'lking through the town trying to find a '),
#  (602, 'ng through the town trying to find a par'),
#  (603, 'through the town trying to find a partic'),
#  (604, 'ough the town trying to find a particula'),
#  (605, 'h the town trying to find a particular \n'),
#  (606, 'he town trying to find a particular \nadd'),
#  (607, 'town trying to find a particular \naddres'),
#  (608, 'n trying to find a particular \naddress, '),
#  (609, 'rying to find a particular \naddress, and'),
#  (610, 'ng to find a particular \naddress, and be'),
#  (611, 'to find a particular \naddress, and being'),
#  (612, 'find a particular \naddress, and being th'),
#  (613, 'd a particular \naddress, and being thoro'),
#  (614, ' particular \naddress, and being thorough'),
#  (615, 'rticular \naddress, and being thoroughly '),
#  (616, 'cular \naddress, and being thoroughly los'),
#  (617, 'ar \naddress, and being thoroughly lost i'),
#  (618, '\naddress, and being thoroughly lost i st'),
#  (619, 'dress, and being thoroughly lost i stopp'),
#  (620, 'ss, and being thoroughly lost i stopped '),
#  (621, ' and being thoroughly lost i stopped to '),
#  (622, 'd being thoroughly lost i stopped to ask'),
#  (623, 'eing thoroughly lost i stopped to ask fo'),
#  (624, 'g thoroughly lost i stopped to ask for d'),
#  (625, 'horoughly lost i stopped to ask for dire'),
#  (626, 'oughly lost i stopped to ask for directi'),
#  (627, 'hly lost i stopped to ask for directions'),
#  (628, ' lost i stopped to ask for directions \nf'),
#  (629, 'st i stopped to ask for directions \nfrom'),
#  (630, 'i stopped to ask for directions \nfrom a '),
#  (631, 'topped to ask for directions \nfrom a man'),
#  (632, 'ped to ask for directions \nfrom a man in'),
#  (633, ' to ask for directions \nfrom a man in th'),
#  (634, ' ask for directions \nfrom a man in the s'),
#  (635, 'k for directions \nfrom a man in the stre'),
#  (636, 'or directions \nfrom a man in the street.'),
#  (637, 'directions \nfrom a man in the street. i '),
#  (638, 'ections \nfrom a man in the street. i kne'),
#  (639, 'ions \nfrom a man in the street. i knew t'),
#  (640, 's \nfrom a man in the street. i knew this'),
#  (641, 'from a man in the street. i knew this mi'),
#  (642, 'm a man in the street. i knew this might'),
#  (643, " man in the street. i knew this mightn't"),
#  (644, "n in the street. i knew this mightn't be"),
#  (645, "n the street. i knew this mightn't be ea"),
#  (646, "he street. i knew this mightn't be easy "),
#  (647, "street. i knew this mightn't be easy bec"),
#  (648, "eet. i knew this mightn't be easy becaus"),
#  (649, ". i knew this mightn't be easy because i"),
#  (650, " knew this mightn't be easy because i do"),
#  (651, "ew this mightn't be easy because i don't"),
#  (652, "this mightn't be easy because i don't \ns"),
#  (653, "s mightn't be easy because i don't \nspea"),
#  (654, "ightn't be easy because i don't \nspeak g"),
#  (655, "tn't be easy because i don't \nspeak germ"),
#  (656, "t be easy because i don't \nspeak german,"),
#  (657, "e easy because i don't \nspeak german, bu"),
#  (658, "asy because i don't \nspeak german, but i"),
#  (659, " because i don't \nspeak german, but i wa"),
#  (660, "cause i don't \nspeak german, but i was s"),
#  (661, "se i don't \nspeak german, but i was stil"),
#  (662, "i don't \nspeak german, but i was still s"),
#  (663, "on't \nspeak german, but i was still surp"),
#  (664, 't \nspeak german, but i was still surpris'),
#  (665, 'speak german, but i was still surprised '),
#  (666, 'ak german, but i was still surprised to '),
#  (667, 'german, but i was still surprised to dis'),
#  (668, 'man, but i was still surprised to discov'),
#  (669, ', but i was still surprised to discover '),
#  (670, 'ut i was still surprised to discover jus'),
#  (671, 'i was still surprised to discover just h'),
#  (672, 'as still surprised to discover just how '),
#  (673, 'still surprised to discover just how muc'),
#  (674, 'll surprised to discover just how much \n'),
#  (675, 'surprised to discover just how much \ndif'),
#  (676, 'prised to discover just how much \ndiffic'),
#  (677, 'sed to discover just how much \ndifficult'),
#  (678, ' to discover just how much \ndifficulty i'),
#  (679, ' discover just how much \ndifficulty i wa'),
#  (680, 'scover just how much \ndifficulty i was h'),
#  (681, 'ver just how much \ndifficulty i was havi'),
#  (682, ' just how much \ndifficulty i was having '),
#  (683, 'st how much \ndifficulty i was having com'),
#  (684, 'how much \ndifficulty i was having commun'),
#  (685, ' much \ndifficulty i was having communica'),
#  (686, 'ch \ndifficulty i was having communicatin'),
#  (687, '\ndifficulty i was having communicating w'),
#  (688, 'fficulty i was having communicating with'),
#  (689, 'culty i was having communicating with th'),
#  (690, 'ty i was having communicating with this '),
#  (691, 'i was having communicating with this par'),
#  (692, 'as having communicating with this partic'),
#  (693, 'having communicating with this particula'),
#  (694, 'ing communicating with this particular m'),
#  (695, ' communicating with this particular man.'),
#  (696, 'mmunicating with this particular man. \ng'),
#  (697, 'nicating with this particular man. \ngrad'),
#  (698, 'ating with this particular man. \ngradual'),
#  (699, 'ng with this particular man. \ngradually '),
#  (700, 'with this particular man. \ngradually the'),
#  (701, 'h this particular man. \ngradually the tr'),
#  (702, 'his particular man. \ngradually the truth'),
#  (703, ' particular man. \ngradually the truth da'),
#  (704, 'rticular man. \ngradually the truth dawne'),
#  (705, 'cular man. \ngradually the truth dawned o'),
#  (706, 'ar man. \ngradually the truth dawned on m'),
#  (707, 'man. \ngradually the truth dawned on me a'),
#  (708, '. \ngradually the truth dawned on me as w'),
#  (709, 'gradually the truth dawned on me as we s'),
#  (710, 'dually the truth dawned on me as we stru'),
#  (711, 'lly the truth dawned on me as we struggl'),
#  (712, ' the truth dawned on me as we struggled '),
#  (713, 'e truth dawned on me as we struggled in '),
#  (714, 'ruth dawned on me as we struggled in vai'),
#  (715, 'h dawned on me as we struggled in vain t'),
#  (716, 'awned on me as we struggled in vain to \n'),
#  (717, 'ed on me as we struggled in vain to \nund'),
#  (718, 'on me as we struggled in vain to \nunders'),
#  (719, 'me as we struggled in vain to \nunderstan'),
#  (720, 'as we struggled in vain to \nunderstand e'),
#  (721, 'we struggled in vain to \nunderstand each'),
#  (722, 'struggled in vain to \nunderstand each ot'),
#  (723, 'uggled in vain to \nunderstand each other'),
#  (724, 'led in vain to \nunderstand each other th'),
#  (725, ' in vain to \nunderstand each other that '),
#  (726, ' vain to \nunderstand each other that of '),
#  (727, 'in to \nunderstand each other that of all'),
#  (728, 'to \nunderstand each other that of all th'),
#  (729, '\nunderstand each other that of all the p'),
#  (730, 'derstand each other that of all the peop'),
#  (731, 'stand each other that of all the people '),
#  (732, 'nd each other that of all the people in '),
#  (733, 'each other that of all the people in inn'),
#  (734, 'h other that of all the people in innsbr'),
#  (735, 'ther that of all the people in innsbruck'),
#  (736, 'r that of all the people in innsbruck i '),
#  (737, 'hat of all the people in innsbruck i cou'),
#  (738, ' of all the people in innsbruck i could '),
#  (739, ' all the people in innsbruck i could hav'),
#  (740, 'l the people in innsbruck i could have \n'),
#  (741, 'he people in innsbruck i could have \nsto'),
#  (742, 'people in innsbruck i could have \nstoppe'),
#  (743, 'ple in innsbruck i could have \nstopped t'),
#  (744, ' in innsbruck i could have \nstopped to a'),
#  (745, ' innsbruck i could have \nstopped to ask,'),
#  (746, 'nsbruck i could have \nstopped to ask, th'),
#  (747, 'ruck i could have \nstopped to ask, the o'),
#  (748, 'k i could have \nstopped to ask, the one '),
#  (749, ' could have \nstopped to ask, the one i h'),
#  (750, 'uld have \nstopped to ask, the one i had '),
#  (751, ' have \nstopped to ask, the one i had pic'),
#  (752, 've \nstopped to ask, the one i had picked'),
#  (753, '\nstopped to ask, the one i had picked di'),
#  (754, 'opped to ask, the one i had picked did n'),
#  (755, 'ed to ask, the one i had picked did not '),
#  (756, 'to ask, the one i had picked did not spe'),
#  (757, 'ask, the one i had picked did not speak '),
#  (758, ', the one i had picked did not speak eng'),
#  (759, 'he one i had picked did not speak englis'),
#  (760, 'one i had picked did not speak english, '),
#  (761, ' i had picked did not speak english, did'),
#  (762, 'had picked did not speak english, did no'),
#  (763, ' picked did not speak english, did not \n'),
#  (764, 'cked did not speak english, did not \nspe'),
#  (765, 'd did not speak english, did not \nspeak '),
#  (766, 'id not speak english, did not \nspeak fre'),
#  (767, 'not speak english, did not \nspeak french'),
#  (768, ' speak english, did not \nspeak french an'),
#  (769, 'eak english, did not \nspeak french and w'),
#  (770, ' english, did not \nspeak french and was '),
#  (771, 'glish, did not \nspeak french and was als'),
#  (772, 'sh, did not \nspeak french and was also d'),
#  (773, ' did not \nspeak french and was also deaf'),
#  (774, 'd not \nspeak french and was also deaf an'),
#  (775, 'ot \nspeak french and was also deaf and d'),
#  (776, '\nspeak french and was also deaf and dumb'),
#  (777, 'eak french and was also deaf and dumb. w'),
#  (778, ' french and was also deaf and dumb. with'),
#  (779, 'ench and was also deaf and dumb. with a '),
#  (780, 'h and was also deaf and dumb. with a ser'),
#  (781, 'nd was also deaf and dumb. with a series'),
#  (782, 'was also deaf and dumb. with a series of'),
#  (783, ' also deaf and dumb. with a series of si'),
#  (784, 'so deaf and dumb. with a series of since'),
#  (785, 'deaf and dumb. with a series of sincerel'),
#  (786, 'f and dumb. with a series of sincerely \n'),
#  (787, 'nd dumb. with a series of sincerely \napo'),
#  (788, 'dumb. with a series of sincerely \napolog'),
#  (789, 'b. with a series of sincerely \napologeti'),
#  (790, 'with a series of sincerely \napologetic h'),
#  (791, 'h a series of sincerely \napologetic hand'),
#  (792, ' series of sincerely \napologetic hand mo'),
#  (793, 'ries of sincerely \napologetic hand movem'),
#  (794, 's of sincerely \napologetic hand movement'),
#  (795, 'f sincerely \napologetic hand movements, '),
#  (796, 'incerely \napologetic hand movements, i d'),
#  (797, 'erely \napologetic hand movements, i dise'),
#  (798, 'ly \napologetic hand movements, i disenta'),
#  (799, '\napologetic hand movements, i disentangl'),
#  (800, 'ologetic hand movements, i disentangled '),
#  (801, 'getic hand movements, i disentangled mys'),
#  (802, 'ic hand movements, i disentangled myself'),
#  (803, 'hand movements, i disentangled myself, a'),
#  (804, 'd movements, i disentangled myself, and '),
#  (805, 'ovements, i disentangled myself, and a f'),
#  (806, 'ments, i disentangled myself, and a few '),
#  (807, 'ts, i disentangled myself, and a few min'),
#  (808, ' i disentangled myself, and a few minute'),
#  (809, 'disentangled myself, and a few minutes l'),
#  (810, 'entangled myself, and a few minutes late'),
#  (811, 'angled myself, and a few minutes later, '),
#  (812, 'led myself, and a few minutes later, on '),
#  (813, ' myself, and a few minutes later, on ano'),
#  (814, 'self, and a few minutes later, on anothe'),
#  (815, 'f, and a few minutes later, on another s'),
#  (816, 'and a few minutes later, on another stre'),
#  (817, ' a few minutes later, on another street,'),
#  (818, 'few minutes later, on another street, i '),
#  (819, ' minutes later, on another street, i sto'),
#  (820, 'nutes later, on another street, i stoppe'),
#  (821, 'es later, on another street, i stopped a'),
#  (822, 'later, on another street, i stopped and '),
#  (823, 'er, on another street, i stopped and ask'),
#  (824, ' on another street, i stopped and asked '),
#  (825, ' another street, i stopped and asked ano'),
#  (826, 'other street, i stopped and asked anothe'),
#  (827, 'er street, i stopped and asked another m'),
#  (828, 'street, i stopped and asked another man '),
#  (829, 'eet, i stopped and asked another man \nwh'),
#  (830, ', i stopped and asked another man \nwho a'),
#  (831, ' stopped and asked another man \nwho also'),
#  (832, 'opped and asked another man \nwho also tu'),
#  (833, 'ed and asked another man \nwho also turne'),
#  (834, 'and asked another man \nwho also turned o'),
#  (835, ' asked another man \nwho also turned out '),
#  (836, 'ked another man \nwho also turned out to '),
#  (837, ' another man \nwho also turned out to be '),
#  (838, 'other man \nwho also turned out to be dea'),
#  (839, 'er man \nwho also turned out to be deaf a'),
#  (840, 'man \nwho also turned out to be deaf and '),
#  (841, ' \nwho also turned out to be deaf and dum'),
#  (842, 'ho also turned out to be deaf and dumb, '),
#  (843, 'also turned out to be deaf and dumb, whi'),
#  (844, 'o turned out to be deaf and dumb, which '),
#  (845, 'urned out to be deaf and dumb, which was'),
#  (846, 'ed out to be deaf and dumb, which was wh'),
#  (847, 'out to be deaf and dumb, which was when '),
#  (848, ' to be deaf and dumb, which was when i b'),
#  (849, ' be deaf and dumb, which was when i boug'),
#  (850, ' deaf and dumb, which was when i bought '),
#  (851, 'af and dumb, which was when i bought \nth'),
#  (852, 'and dumb, which was when i bought \nthe b'),
#  (853, ' dumb, which was when i bought \nthe beer'),
#  (854, 'mb, which was when i bought \nthe beers. '),
#  (855, ' which was when i bought \nthe beers.  \ni'),
#  (856, 'ich was when i bought \nthe beers.  \ni ve'),
#  (857, ' was when i bought \nthe beers.  \ni ventu'),
#  (858, 's when i bought \nthe beers.  \ni ventured'),
#  (859, 'hen i bought \nthe beers.  \ni ventured ba'),
#  (860, ' i bought \nthe beers.  \ni ventured back '),
#  (861, 'bought \nthe beers.  \ni ventured back ont'),
#  (862, 'ght \nthe beers.  \ni ventured back onto t'),
#  (863, ' \nthe beers.  \ni ventured back onto the '),
#  (864, 'he beers.  \ni ventured back onto the str'),
#  (865, 'beers.  \ni ventured back onto the street'),
#  (866, 'rs.  \ni ventured back onto the street. i'),
#  (867, '  \ni ventured back onto the street. i tr'),
#  (868, 'i ventured back onto the street. i tried'),
#  (869, 'entured back onto the street. i tried ag'),
#  (870, 'ured back onto the street. i tried again'),
#  (871, 'd back onto the street. i tried again.  '),
#  (872, 'ack onto the street. i tried again.  \nwh'),
#  (873, ' onto the street. i tried again.  \nwhen '),
#  (874, 'to the street. i tried again.  \nwhen the'),
#  (875, 'the street. i tried again.  \nwhen the th'),
#  (876, ' street. i tried again.  \nwhen the third'),
#  (877, 'reet. i tried again.  \nwhen the third ma'),
#  (878, 't. i tried again.  \nwhen the third man i'),
#  (879, 'i tried again.  \nwhen the third man i sp'),
#  (880, 'ried again.  \nwhen the third man i spoke'),
#  (881, 'd again.  \nwhen the third man i spoke to'),
#  (882, 'gain.  \nwhen the third man i spoke to tu'),
#  (883, 'n.  \nwhen the third man i spoke to turne'),
#  (884, ' \nwhen the third man i spoke to turned o'),
#  (885, 'hen the third man i spoke to turned out '),
#  (886, ' the third man i spoke to turned out to '),
#  (887, 'e third man i spoke to turned out to be '),
#  (888, 'hird man i spoke to turned out to be dea'),
#  (889, 'd man i spoke to turned out to be deaf a'),
#  (890, 'an i spoke to turned out to be deaf and '),
#  (891, 'i spoke to turned out to be deaf and dum'),
#  (892, 'poke to turned out to be deaf and dumb \n'),
#  (893, 'e to turned out to be deaf and dumb \nand'),
#  (894, 'o turned out to be deaf and dumb \nand al'),
#  (895, 'urned out to be deaf and dumb \nand also '),
#  (896, 'ed out to be deaf and dumb \nand also bli'),
#  (897, 'out to be deaf and dumb \nand also blind '),
#  (898, ' to be deaf and dumb \nand also blind i b'),
#  (899, ' be deaf and dumb \nand also blind i bega'),
#  (900, ' deaf and dumb \nand also blind i began t'),
#  (901, 'af and dumb \nand also blind i began to f'),
#  (902, 'and dumb \nand also blind i began to feel'),
#  (903, ' dumb \nand also blind i began to feel a '),
#  (904, 'mb \nand also blind i began to feel a ter'),
#  (905, '\nand also blind i began to feel a terrib'),
#  (906, 'd also blind i began to feel a terrible '),
#  (907, 'lso blind i began to feel a terrible wei'),
#  (908, ' blind i began to feel a terrible weight'),
#  (909, 'ind i began to feel a terrible weight se'),
#  (910, ' i began to feel a terrible weight settl'),
#  (911, 'began to feel a terrible weight settling'),
#  (912, 'an to feel a terrible weight settling on'),
#  (913, 'to feel a terrible weight settling on my'),
#  (914, 'feel a terrible weight settling on my \ns'),
#  (915, 'l a terrible weight settling on my \nshou'),
#  (916, ' terrible weight settling on my \nshoulde'),
#  (917, 'rrible weight settling on my \nshoulders;'),
#  (918, 'ble weight settling on my \nshoulders; wh'),
#  (919, ' weight settling on my \nshoulders; where'),
#  (920, 'ight settling on my \nshoulders; wherever'),
#  (921, 't settling on my \nshoulders; wherever i '),
#  (922, 'ettling on my \nshoulders; wherever i loo'),
#  (923, 'ling on my \nshoulders; wherever i looked'),
#  (924, 'g on my \nshoulders; wherever i looked th'),
#  (925, 'n my \nshoulders; wherever i looked the t'),
#  (926, 'y \nshoulders; wherever i looked the tree'),
#  (927, 'shoulders; wherever i looked the trees a'),
#  (928, 'ulders; wherever i looked the trees and '),
#  (929, 'ers; wherever i looked the trees and bui'),
#  (930, '; wherever i looked the trees and buildi'),
#  (931, 'herever i looked the trees and buildings'),
#  (932, 'ever i looked the trees and buildings to'),
#  (933, 'r i looked the trees and buildings took '),
#  (934, ' looked the trees and buildings took on '),
#  (935, 'oked the trees and buildings took on dar'),
#  (936, 'd the trees and buildings took on dark a'),
#  (937, 'he trees and buildings took on dark and '),
#  (938, 'trees and buildings took on dark and \nme'),
#  (939, 'es and buildings took on dark and \nmenac'),
#  (940, 'and buildings took on dark and \nmenacing'),
#  (941, ' buildings took on dark and \nmenacing as'),
#  (942, 'ildings took on dark and \nmenacing aspec'),
#  (943, 'ings took on dark and \nmenacing aspects.'),
#  (944, 's took on dark and \nmenacing aspects. i '),
#  (945, 'ook on dark and \nmenacing aspects. i pul'),
#  (946, ' on dark and \nmenacing aspects. i pulled'),
#  (947, ' dark and \nmenacing aspects. i pulled my'),
#  (948, 'rk and \nmenacing aspects. i pulled my co'),
#  (949, 'and \nmenacing aspects. i pulled my coat '),
#  (950, ' \nmenacing aspects. i pulled my coat tig'),
#  (951, 'enacing aspects. i pulled my coat tightl'),
#  (952, 'cing aspects. i pulled my coat tightly a'),
#  (953, 'g aspects. i pulled my coat tightly arou'),
#  (954, 'spects. i pulled my coat tightly around '),
#  (955, 'cts. i pulled my coat tightly around me '),
#  (956, '. i pulled my coat tightly around me and'),
#  (957, ' pulled my coat tightly around me and hu'),
#  (958, 'lled my coat tightly around me and hurri'),
#  (959, 'd my coat tightly around me and hurried '),
#  (960, 'y coat tightly around me and hurried \nlu'),
#  (961, 'oat tightly around me and hurried \nlurch'),
#  (962, ' tightly around me and hurried \nlurching'),
#  (963, 'ghtly around me and hurried \nlurching do'),
#  (964, 'ly around me and hurried \nlurching down '),
#  (965, 'around me and hurried \nlurching down the'),
#  (966, 'und me and hurried \nlurching down the st'),
#  (967, ' me and hurried \nlurching down the stree'),
#  (968, ' and hurried \nlurching down the street, '),
#  (969, 'd hurried \nlurching down the street, whi'),
#  (970, 'urried \nlurching down the street, whippe'),
#  (971, 'ied \nlurching down the street, whipped b'),
#  (972, ' \nlurching down the street, whipped by a'),
#  (973, 'urching down the street, whipped by a su'),
#  (974, 'hing down the street, whipped by a sudde'),
#  (975, 'g down the street, whipped by a sudden g'),
#  (976, 'own the street, whipped by a sudden gust'),
#  (977, ' the street, whipped by a sudden gusting'),
#  (978, 'e street, whipped by a sudden gusting wi'),
#  (979, 'treet, whipped by a sudden gusting wind.'),
#  (980, 'et, whipped by a sudden gusting wind. i '),
#  (981, ' whipped by a sudden gusting wind. i \nbu'),
#  (982, 'ipped by a sudden gusting wind. i \nbumpe'),
#  (983, 'ed by a sudden gusting wind. i \nbumped i'),
#  (984, 'by a sudden gusting wind. i \nbumped into'),
#  (985, 'a sudden gusting wind. i \nbumped into so'),
#  (986, 'udden gusting wind. i \nbumped into someo'),
#  (987, 'en gusting wind. i \nbumped into someone '),
#  (988, 'gusting wind. i \nbumped into someone and'),
#  (989, 'ting wind. i \nbumped into someone and st'),
#  (990, 'g wind. i \nbumped into someone and stamm'),
#  (991, 'ind. i \nbumped into someone and stammere'),
#  (992, '. i \nbumped into someone and stammered a'),
#  (993, ' \nbumped into someone and stammered an a'),
#  (994, 'umped into someone and stammered an apol'),
#  (995, 'ed into someone and stammered an apology'),
#  (996, 'into someone and stammered an apology, b'),
#  (997, 'o someone and stammered an apology, but '),
#  (998, 'omeone and stammered an apology, but he '),
#  (999, 'one and stammered an apology, but he was'),
#  ...]

# %%
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        X[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1

# %%
y
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [ True, False, False, ..., False, False, False]], dtype=bool)
